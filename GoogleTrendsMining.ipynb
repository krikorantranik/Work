# %% [markdown]
# <a href="https://colab.research.google.com/github/krikorantranik/Work/blob/main/GoogleTrendsMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project is a very ambitious attempt to predict the gas prices based on three algorithms: NLP (word2vec) to find words related to 'Oil', time series decomposition after Fourier analysis (to predict each time effect separately), and neural networks with Keras to predict, using the frequency of word searches in Google, the random variation of the oil price.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import MSTL
# !pip install klib
import klib
from scipy import spatial
import gensim.downloader as api
from statsmodels.tsa.seasonal import MSTL
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from datetime import timedelta
import tensorflow as tf
import math
import nltk
nltk.download('wordnet')
# !pip install pmdarima
from pmdarima import auto_arima
# Out:
# Requirement already satisfied: klib in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from klib) (3.1.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from klib) (3.7.1)
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in /usr/local/lib/python3.10/dist-packages (from klib) (1.23.5)
# Requirement already satisfied: pandas<3.0,>=1.2 in /usr/local/lib/python3.10/dist-packages (from klib) (1.5.3)
# Requirement already satisfied: plotly<6.0.0,>=5.2.2 in /usr/local/lib/python3.10/dist-packages (from klib) (5.15.0)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from klib) (1.11.3)
# Requirement already satisfied: screeninfo<0.9.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from klib) (0.8.1)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.10/dist-packages (from klib) (0.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4.0.0,>=3.0.3->klib) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.2->klib) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.2.2->klib) (8.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.16.0)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.3)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.11.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.6)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3

# %% [markdown]
# Word2Vec is the right choice for the NLP portion of the analysis because: 1) It is trained to be used for similarities-distances, unlike BERT, for example, which is usually trained for different downstream tasks, like masking. 2) It generates word embeddings, which is what we are trying to obtain and compare.
#
# I am using here a library called gensim downloader, which has a set of pretrained Word2Vec models with huge datasets, so that we don't have to suffer through that. In this case, it is fine because we are going to use this over Google data, which is supposed to be clean.
#
# I am downloading two big models.

# %%
model1 = api.load("glove-wiki-gigaword-200")
model2 = api.load("glove-twitter-100")
# Out:
# [==================================================] 100.0% 252.1/252.1MB downloaded
# [==================================================] 100.0% 387.1/387.1MB downloaded

# %% [markdown]
# I am defining a function to get the most similar words from both models, and average them out. See the results of a test

# %%
def close_words(wrd):
 tbl1 = pd.DataFrame(model1.most_similar(wrd, topn=10), columns=['word','siml']).set_index('word')
 tbl2 = pd.DataFrame(model2.most_similar(wrd, topn=10), columns=['word','siml']).set_index('word')
 tbl = pd.concat((tbl1, tbl2), axis=1).mean(axis=1)
 tbl = pd.DataFrame(tbl).sort_values(0, ascending=False)
 return tbl

dfs = []

# %% [markdown]
# Here I do a search on several keywords I think are related to oil or oil prices. First I start with the word oil, then I look for other words that come from the list, following a "chain". The step after this one "saves" the search results to a list of dataframes.

# %%
search = 'barrels'
wordsim = close_words(search)

lemmatizer = WordNetLemmatizer()
wordsim['Lemma'] = wordsim.index
wordsim['Lemma'] = wordsim['Lemma'].apply(lambda x: lemmatizer.lemmatize(x))
wordsim
# Out:
#                  0     Lemma
# word
# crude     0.727617     crude
# bpd       0.709313       bpd
# barrel    0.634681    barrel
# 900,000   0.610963   900,000
# shotguns  0.598264   shotgun
# tons      0.595889       ton
# bourbon   0.595722   bourbon
# output    0.594559    output
# oil       0.593525       oil
# bombs     0.592140      bomb
# gasoline  0.590114  gasoline
# tonnes    0.587787     tonne
# gallons   0.579721    gallon
# tankers   0.568611    tanker
# threes    0.566065     three
# pints     0.554012      pint
# scotch    0.548751    scotch
# methane   0.548206   methane

# %%
dfs.append(wordsim)

# %% [markdown]
# Now I save it all to a list, which I am going to use to search in Google Trends using a third party API called Google Trends Scraper (https://apify.com/emastra/google-trends-scraper)

# %%
finaldf = pd.concat(dfs, ignore_index=True).groupby('Lemma').mean()
finaldf.to_csv("finaldf.csv")

# %% [markdown]
# Part 2:
#
# Once the scraper is done, I save the results and import them. They are in a transposed format, so I account for that next and five the time series their format, same with the numbers

# %%
workdf = pd.read_csv("dataset_google-trends-scraper_2023-10-17_07-39-06-381.csv")
workdf = workdf.T
df2 = workdf.iloc[[-1]]
workdf = workdf[:-1]
workdf.columns = list(df2.values[0])
workdf['Timestamp'] = workdf.index
workdf['Timestamp'] = pd.to_datetime(workdf['Timestamp'], format='%b %d, %Y')
workdf = workdf.sort_values('Timestamp')
workdf = workdf.set_index('Timestamp')
workdf = workdf.apply(pd.to_numeric, errors='coerce', axis=1)
workdf
# Out:
#             arabia  air-conditioning  arab  atmosphere  aviation  atomic  \
# Timestamp
# 2018-10-21       8                31    55          60        85      19
# 2018-10-28       6                39    55          63        90      20
# 2018-11-04       6                32    49          55        82      19
# 2018-11-11       6                34    50          64        83      19
# 2018-11-18       6                25    48          53        77      16
# ...            ...               ...   ...         ...       ...     ...
# 2023-09-10       9                49    51          83        88      27
# 2023-09-17      10                43    55          79        91      25
# 2023-09-24      10                44    53          75        90      25
# 2023-10-01       9                48    54          75        85      27
# 2023-10-08      10                47    59          78        89      25
#
#             bahrain  banking  barrel  biofuel  ...  refinery  aerospace  uae  \
# Timestamp                                      ...
# 2018-10-21       30       88      72       51  ...        42         66   42
# 2018-10-28       30      100      79       56  ...        43         69   42
# 2018-11-04       30       86      66       64  ...        37         65   39
# 2018-11-11       32       93      73       54  ...        44         71   39
# 2018-11-18       29       83      84       50  ...        37         57   45
# ...             ...      ...     ...      ...  ...       ...        ...  ...
# 2023-09-10       36       52      48      100  ...        41         85   61
# 2023-09-17       40       51      47       66  ...        41         83   63
# 2023-09-24       37       56      50       59  ...        37         80   63
# 2023-10-01       36       60      46       56  ...        35         78   59
# 2023-10-08       35       55      46       56  ...        39         74   59
#
#             truck  suv  war  unrest  groundwater  gulf  utility
# Timestamp
# 2018-10-21     58   67   40       7           65    49       83
# 2018-10-28     62   67   39       8           65    56       91
# 2018-11-04     61   65   45       7           59    45       92
# 2018-11-11     63   69   45       9           63    48       83
# 2018-11-18     59   66   38       8           55    42       85
# ...           ...  ...  ...     ...          ...   ...      ...
# 2023-09-10     58   78   34       7           57    44       86
# 2023-09-17     60   78   38       9           57    44       87
# 2023-09-24     57   72   36       9           62    41       89
# 2023-10-01     55   69   39      10           65    42       85
# 2023-10-08     57   71   71      15           64    44       86
#
# [260 rows x 188 columns]

# %% [markdown]
# After much iteration, I found that the predictors also have some seasonality in them, so I decompose them using a schedule of 52 and 104 weeks (one and two years)

# %%
a = []
for col in workdf.columns:
 sea = MSTL(workdf[col], periods=(52, 104)).fit()
 res = pd.DataFrame(sea.resid)
 res.columns = [col]
 a.append(res)

xres = pd.concat(a, axis=1)
xres
# Out:
#               arabia  air-conditioning      arab  atmosphere  aviation  \
# Timestamp
# 2018-10-21 -0.330499          0.604723 -0.711202   -0.598436 -2.731577
# 2018-10-28 -0.481795          2.734440  0.047960    0.310680 -0.024611
# 2018-11-04 -0.177792         -0.294047 -0.102996    0.159584  2.532669
# 2018-11-11 -0.632351         -0.895578 -0.407717    1.676017 -1.134711
# 2018-11-18  0.278555         -4.987020 -0.407916    0.463205 -1.611938
# ...              ...               ...       ...         ...       ...
# 2023-09-10  0.741927          1.275390 -1.734964    0.535306 -1.297249
# 2023-09-17  0.147356          1.577602 -0.820589   -1.283480  0.541336
# 2023-09-24  0.159071         -0.704391 -0.514733   -0.824099  0.407160
# 2023-10-01 -0.284198          2.328798  1.763548    0.697252 -0.939905
# 2023-10-08  0.183420          2.325932  1.462108    2.068277 -0.617336
#
#               atomic   bahrain   banking    barrel   biofuel  ...  refinery  \
# Timestamp                                                     ...
# 2018-10-21 -0.931098  1.257727  0.655854  1.902172  0.275871  ...  0.303491
# 2018-10-28 -0.783317  0.948780  1.728312  2.819447  1.483197  ... -0.771127
# 2018-11-04 -0.483684  1.854599  0.370486  2.225104  4.666172  ... -0.176217
# 2018-11-11  0.120042  1.088970  1.589684  1.321502  3.293487  ...  0.874353
# 2018-11-18 -0.489912  1.236553  1.143898  0.263799  1.467589  ... -1.412086
# ...              ...       ...       ...       ...       ...  ...       ...
# 2023-09-10  0.340192  0.293424 -0.994948  0.246739  8.077910  ...  0.840155
# 2023-09-17 -0.108586  1.055370 -1.137541 -1.419929  2.327587  ... -2.185963
# 2023-09-24 -0.103025  1.210704 -0.824479 -2.329986  1.725365  ... -1.270714
# 2023-10-01  0.055906  0.607199 -1.572963 -2.630996 -1.449209  ... -1.871513
# 2023-10-08  0.214998  0.762644  0.714541 -2.325679  2.507749  ...  2.990153
#
#             aerospace       uae     truck       suv       war     unrest  \
# Timestamp
# 2018-10-21  -2.465895  5.780474 -1.301850 -1.109410  1.250140  -1.423068
# 2018-10-28   4.332443 -0.880070 -0.231644  0.261295  1.240100  -5.524777
# 2018-11-04   2.186717  0.803009  1.293980  1.936709  2.442494 -15.244209
# 2018-11-11   0.645085 -0.397407  0.389966  1.637852 -1.062094  -0.818185
# 2018-11-18   0.472478  5.673089  0.404718 -0.479705 -2.741562   0.396400
# ...               ...       ...       ...       ...       ...        ...
# 2023-09-10   0.791406 -1.218987 -0.772352  1.828134 -0.539027   0.525010
# 2023-09-17  -0.101669  0.298315  0.291093  0.604832  0.523190   0.667005
# 2023-09-24   1.433866  1.367192 -0.012060  1.660539  3.557171   1.565698
# 2023-10-01   0.693238 -1.371884 -1.983768  0.284040  3.557953   1.553618
# 2023-10-08   0.410618  1.358073 -0.768772  1.792394  7.655908   2.907234
#
#             groundwater      gulf   utility
# Timestamp
# 2018-10-21     0.658969 -0.868316 -1.113794
# 2018-10-28     0.198041 -0.102704  0.102789
# 2018-11-04     2.623653  0.057565  2.683083
# 2018-11-11     0.189251  0.368441  0.254250
# 2018-11-18    -0.118083  0.073762  0.862260
# ...                 ...       ...       ...
# 2023-09-10    -0.155463 -0.733190 -0.854110
# 2023-09-17     1.226761  0.488243 -2.363483
# 2023-09-24     1.997020  0.346123  0.682640
# 2023-10-01     0.497381 -0.556223 -0.216898
# 2023-10-08     1.119745  0.817718  0.095306
#
# [260 rows x 188 columns]

# %% [markdown]
# Next, I import the gas prices from government data, apply format to them as well

# %%
ydf = pd.read_csv("GASREGW.csv")
from datetime import timedelta
ydf['DATE'] = pd.to_datetime(ydf['DATE'], format='%Y-%m-%d')  - timedelta(days=1)
ydf = ydf.sort_values('DATE')
ydf = ydf.set_index('DATE')
ydf = ydf.apply(pd.to_numeric, errors='coerce', axis=1)
ydf
# Out:
#             GASREGW
# DATE
# 2018-10-14    2.879
# 2018-10-21    2.841
# 2018-10-28    2.811
# 2018-11-04    2.753
# 2018-11-11    2.686
# ...             ...
# 2023-09-17    3.878
# 2023-09-24    3.837
# 2023-10-01    3.798
# 2023-10-08    3.684
# 2023-10-15    3.576
#
# [262 rows x 1 columns]

# %% [markdown]
# Now, I want to explore more about the seasonality of oil prices. In order to do that, I do a Fourier transform on the series to find the period (in weeks) of the possible components. I then extract those components with higher amplitude and use those as the input for the seasonal decomposition.

# %%
from scipy.fft import fft, fftfreq
import numpy as np
yf = fft(ydf['GASREGW'].values)
N = len(ydf)
xf = 1/(fftfreq(N, d=1.0))
nyf = np.abs(yf)
four = pd.DataFrame({'Period':xf, 'Amp':nyf})
four = four[(four['Period']>0) & (four['Period']<=200)]
four = four.sort_values(['Period'], ascending=True)
four['Period'] = four['Period'].apply(lambda x: math.floor(x))
four = four.groupby('Period').max().reset_index(drop=False)
four = four.sort_values('Amp', ascending=False).head(5)
four
# Out:
# <ipython-input-33-440085b02262>:5: RuntimeWarning: divide by zero encountered in divide
#   xf = 1/(fftfreq(N, d=1.0))
#     Period        Amp
# 26      65  35.751044
# 25      52  30.918006
# 28     131  27.718713
# 22      32  20.674774
# 23      37  12.007991

# %% [markdown]
# This is the time-series decomposition. Note that I replaced 131 weeks with 104 weeks, since I can't go further with the data I have.
#
# The results are very nice, I believe. I see a clear trend and seasonal components.
#
# What I am going to predict is the residual.

# %%
seas = MSTL(ydf['GASREGW'], periods=(32, 37, 52, 65, 104)).fit()
seas.plot()
plt.tight_layout()
plt.show()

# %%
ydf['seasonal_32'] = seas.seasonal['seasonal_32']
ydf['seasonal_37'] = seas.seasonal['seasonal_37']
ydf['seasonal_52'] = seas.seasonal['seasonal_52']
ydf['seasonal_65'] = seas.seasonal['seasonal_65']
ydf['seasonal_104'] = seas.seasonal['seasonal_104']
ydf['Trend'] = seas.trend
ydf['Resid'] = seas.resid
ydf['Diff'] = ydf['Resid'].diff(-1)
ydf
# Out:
#             GASREGW  seasonal_32  seasonal_37  seasonal_52  seasonal_65  \
# DATE
# 2018-10-14    2.879     0.238169     0.062054    -0.082581     0.091637
# 2018-10-21    2.841     0.221195     0.036862    -0.071466     0.079177
# 2018-10-28    2.811     0.174373     0.010197     0.071157     0.033679
# 2018-11-04    2.753     0.127687    -0.002368     0.071777     0.057184
# 2018-11-11    2.686     0.101349    -0.033738     0.063600     0.058681
# ...             ...          ...          ...          ...          ...
# 2023-09-17    3.878     0.175896    -0.101218     0.201309     0.202861
# 2023-09-24    3.837     0.124219    -0.082241     0.204170     0.188452
# 2023-10-01    3.798     0.076408    -0.057333     0.211849     0.164004
# 2023-10-08    3.684    -0.028506    -0.027433     0.192238     0.119230
# 2023-10-15    3.576    -0.104454    -0.004122     0.122026     0.108716
#
#             seasonal_104     Trend     Resid      Diff
# DATE
# 2018-10-14      0.374215  2.082253  0.113252  0.004813
# 2018-10-21      0.380888  2.085904  0.108440  0.017041
# 2018-10-28      0.340629  2.089565  0.091399  0.005704
# 2018-11-04      0.319787  2.093238  0.085695  0.010659
# 2018-11-11      0.324151  2.096923  0.075036  0.004828
# ...                  ...       ...       ...       ...
# 2023-09-17     -1.007587  4.483772 -0.077033 -0.002312
# 2023-09-24     -1.018873  4.495993 -0.074721 -0.002727
# 2023-10-01     -1.033141  4.508206 -0.071994  0.010145
# 2023-10-08     -1.009802  4.520411 -0.082138  0.012737
# 2023-10-15     -0.983899  4.532609 -0.094876       NaN
#
# [262 rows x 9 columns]

# %% [markdown]
# Scaling the input data

# %%
def properscaler(simio):
 scaler = StandardScaler()
 resultsWordstrans = scaler.fit_transform(simio)
 resultsWordstrans = pd.DataFrame(resultsWordstrans)
 resultsWordstrans.index = simio.index
 resultsWordstrans.columns = simio.columns
 return resultsWordstrans

xresidualsS = properscaler(xres)
xresidualsS
# Out:
#               arabia  air-conditioning      arab  atmosphere  aviation  \
# Timestamp
# 2018-10-21 -0.070350          0.165959 -0.408323   -0.314853 -1.083271
# 2018-10-28 -0.131793          0.992183  0.052995    0.250077  0.392392
# 2018-11-04 -0.008334         -0.182719 -0.038735    0.156185  1.786455
# 2018-11-11 -0.192936         -0.416082 -0.223905    1.098507 -0.212763
# 2018-11-18  0.176994         -2.003357 -0.224026    0.344857 -0.472916
# ...              ...               ...       ...         ...       ...
# 2023-09-10  0.365176          0.426144 -1.030429    0.389662 -0.301368
# 2023-09-17  0.123713          0.543388 -0.474794   -0.740544  0.700909
# 2023-09-24  0.128470         -0.341911 -0.288935   -0.455082  0.627765
# 2023-10-01 -0.051547          0.834814  1.095502    0.490296 -0.106567
# 2023-10-08  0.138359          0.833702  0.912327    1.342260  0.069276
#
#               atomic   bahrain   banking    barrel   biofuel  ...  refinery  \
# Timestamp                                                     ...
# 2018-10-21 -0.366781  0.499878  0.587424  1.126400  0.226270  ...  0.318641
# 2018-10-28 -0.293084  0.390117  1.510660  1.697744  0.763678  ... -0.232448
# 2018-11-04 -0.143659  0.711931  0.341763  1.327545  2.180489  ...  0.072635
# 2018-11-11  0.157413  0.439923  1.391321  0.764717  1.569477  ...  0.611392
# 2018-11-18 -0.146766  0.492355  1.007562  0.105904  0.756730  ... -0.561147
# ...              ...       ...       ...       ...       ...  ...       ...
# 2023-09-10  0.267200  0.157286 -0.833684  0.095277  3.699129  ...  0.593855
# 2023-09-17  0.043398  0.427986 -0.956437 -0.942842  1.139534  ... -0.958008
# 2023-09-24  0.046172  0.483172 -0.686934 -1.509691  0.871472  ... -0.488648
# 2023-10-01  0.125429  0.268763 -1.331273 -1.697181 -0.541601  ... -0.796751
# 2023-10-08  0.204767  0.323988  0.637946 -1.507008  1.219728  ...  1.696423
#
#             aerospace       uae     truck       suv       war    unrest  \
# Timestamp
# 2018-10-21  -0.845790  2.133580 -1.549842 -0.895158  0.686088 -0.421696
# 2018-10-28   2.466582 -0.423657 -0.372133  0.005122  0.681242 -1.526335
# 2018-11-04   1.421114  0.222541  1.306740  1.105534  1.261611 -4.143893
# 2018-11-11   0.669981 -0.238344  0.311918  0.909245 -0.429977 -0.258794
# 2018-11-18   0.585881  2.092351  0.328152 -0.481567 -1.240620  0.068309
# ...               ...       ...       ...       ...       ...       ...
# 2023-09-10   0.741273 -0.553780 -0.967155  1.034223 -0.177504  0.102945
# 2023-09-17   0.306138  0.028770  0.203112  0.230757  0.335205  0.141186
# 2023-09-24   1.054300  0.439152 -0.130491  0.924146  1.799642  0.383215
# 2023-10-01   0.693442 -0.612483 -2.300258  0.020061  1.800019  0.379961
# 2023-10-08   0.555741  0.435651 -0.963215  1.010748  3.778013  0.744506
#
#             groundwater      gulf   utility
# Timestamp
# 2018-10-21     0.613868 -0.401372 -0.694890
# 2018-10-28     0.332409 -0.024471  0.171016
# 2018-11-04     1.813575  0.054427  2.007549
# 2018-11-11     0.327042  0.207467  0.278819
# 2018-11-18     0.139372  0.062400  0.711572
# ...                 ...       ...       ...
# 2023-09-10     0.116547 -0.334851 -0.510059
# 2023-09-17     0.960582  0.266444 -1.584361
# 2023-09-24     1.430930  0.196480  0.583727
# 2023-10-01     0.515197 -0.247733 -0.056522
# 2023-10-08     0.895235  0.428640  0.165690
#
# [260 rows x 188 columns]

# %% [markdown]
# What I am going to predict, after exploring other options, is the differential of the residual, so I calculate that and use it as response variable.

# %%
DF = pd.merge(xresidualsS, ydf, left_index=True, right_index=True)
DF['Diff'] = DF['Diff'].apply(lambda x: math.tanh(x))
DF.index = workdf.index
DF = DF.dropna()
DFf = DF.drop(columns=['GASREGW','seasonal_32','seasonal_37','seasonal_52','seasonal_65','seasonal_104','Trend','Resid'])
DFf
# Out:
#               arabia  air-conditioning      arab  atmosphere  aviation  \
# Timestamp
# 2018-10-21 -0.070350          0.165959 -0.408323   -0.314853 -1.083271
# 2018-10-28 -0.131793          0.992183  0.052995    0.250077  0.392392
# 2018-11-04 -0.008334         -0.182719 -0.038735    0.156185  1.786455
# 2018-11-11 -0.192936         -0.416082 -0.223905    1.098507 -0.212763
# 2018-11-18  0.176994         -2.003357 -0.224026    0.344857 -0.472916
# ...              ...               ...       ...         ...       ...
# 2023-09-10  0.365176          0.426144 -1.030429    0.389662 -0.301368
# 2023-09-17  0.123713          0.543388 -0.474794   -0.740544  0.700909
# 2023-09-24  0.128470         -0.341911 -0.288935   -0.455082  0.627765
# 2023-10-01 -0.051547          0.834814  1.095502    0.490296 -0.106567
# 2023-10-08  0.138359          0.833702  0.912327    1.342260  0.069276
#
#               atomic   bahrain   banking    barrel   biofuel  ...  aerospace  \
# Timestamp                                                     ...
# 2018-10-21 -0.366781  0.499878  0.587424  1.126400  0.226270  ...  -0.845790
# 2018-10-28 -0.293084  0.390117  1.510660  1.697744  0.763678  ...   2.466582
# 2018-11-04 -0.143659  0.711931  0.341763  1.327545  2.180489  ...   1.421114
# 2018-11-11  0.157413  0.439923  1.391321  0.764717  1.569477  ...   0.669981
# 2018-11-18 -0.146766  0.492355  1.007562  0.105904  0.756730  ...   0.585881
# ...              ...       ...       ...       ...       ...  ...        ...
# 2023-09-10  0.267200  0.157286 -0.833684  0.095277  3.699129  ...   0.741273
# 2023-09-17  0.043398  0.427986 -0.956437 -0.942842  1.139534  ...   0.306138
# 2023-09-24  0.046172  0.483172 -0.686934 -1.509691  0.871472  ...   1.054300
# 2023-10-01  0.125429  0.268763 -1.331273 -1.697181 -0.541601  ...   0.693442
# 2023-10-08  0.204767  0.323988  0.637946 -1.507008  1.219728  ...   0.555741
#
#                  uae     truck       suv       war    unrest  groundwater  \
# Timestamp
# 2018-10-21  2.133580 -1.549842 -0.895158  0.686088 -0.421696     0.613868
# 2018-10-28 -0.423657 -0.372133  0.005122  0.681242 -1.526335     0.332409
# 2018-11-04  0.222541  1.306740  1.105534  1.261611 -4.143893     1.813575
# 2018-11-11 -0.238344  0.311918  0.909245 -0.429977 -0.258794     0.327042
# 2018-11-18  2.092351  0.328152 -0.481567 -1.240620  0.068309     0.139372
# ...              ...       ...       ...       ...       ...          ...
# 2023-09-10 -0.553780 -0.967155  1.034223 -0.177504  0.102945     0.116547
# 2023-09-17  0.028770  0.203112  0.230757  0.335205  0.141186     0.960582
# 2023-09-24  0.439152 -0.130491  0.924146  1.799642  0.383215     1.430930
# 2023-10-01 -0.612483 -2.300258  0.020061  1.800019  0.379961     0.515197
# 2023-10-08  0.435651 -0.963215  1.010748  3.778013  0.744506     0.895235
#
#                 gulf   utility      Diff
# Timestamp
# 2018-10-21 -0.401372 -0.694890  0.017040
# 2018-10-28 -0.024471  0.171016  0.005704
# 2018-11-04  0.054427  2.007549  0.010659
# 2018-11-11  0.207467  0.278819  0.004828
# 2018-11-18  0.062400  0.711572  0.009515
# ...              ...       ...       ...
# 2023-09-10 -0.334851 -0.510059 -0.001680
# 2023-09-17  0.266444 -1.584361 -0.002312
# 2023-09-24  0.196480  0.583727 -0.002727
# 2023-10-01 -0.247733 -0.056522  0.010144
# 2023-10-08  0.428640  0.165690  0.012737
#
# [260 rows x 189 columns]

# %%
corr = DFf.corr(method = 'pearson')
sns.heatmap(corr, cmap=sns.color_palette("vlag", as_cmap=True))
# Out:
# <Axes: >

# %%
corr.sort_values('Diff', ascending=False)['Diff'][1:]
# Out:
# realpolitik      0.207564
# pollution        0.203622
# radioactivity    0.202242
# import           0.174830
# oilfield         0.174045
#                    ...
# propane         -0.107660
# mining          -0.118681
# heating         -0.123593
# hvac            -0.127034
# riyadh          -0.141807
# Name: Diff, Length: 188, dtype: float64

# %% [markdown]
# After a small exploration of the correlation, I proceed with the train and test split, with the main difference that I split along a time line; the most recent weeks are what I want to predict, so I use those as "tests."

# %%
finaleval=DFf[-12:]
subset=DFf[:-12]

x_subset = subset.drop(columns=["Diff"]).to_numpy()
y_subset = subset['Diff'].to_numpy()
x_finaleval = finaleval.drop(columns=["Diff"]).to_numpy()
y_finaleval = finaleval[['Diff']].to_numpy()

subset
# Out:
#               arabia  air-conditioning      arab  atmosphere  aviation  \
# Timestamp
# 2018-10-21 -0.070350          0.165959 -0.408323   -0.314853 -1.083271
# 2018-10-28 -0.131793          0.992183  0.052995    0.250077  0.392392
# 2018-11-04 -0.008334         -0.182719 -0.038735    0.156185  1.786455
# 2018-11-11 -0.192936         -0.416082 -0.223905    1.098507 -0.212763
# 2018-11-18  0.176994         -2.003357 -0.224026    0.344857 -0.472916
# ...              ...               ...       ...         ...       ...
# 2023-06-18 -0.050365         -0.034081  0.527038   -1.142377  0.617063
# 2023-06-25 -0.170429         -1.271861  0.619187   -1.046235  0.952096
# 2023-07-02 -0.105596         -0.504963  0.158660   -1.611168 -0.699346
# 2023-07-09 -0.102229          0.435727  0.068468   -1.798572  1.455848
# 2023-07-16 -0.098737         -2.036853  0.623667   -0.948262  0.966143
#
#               atomic   bahrain   banking    barrel   biofuel  ...  aerospace  \
# Timestamp                                                     ...
# 2018-10-21 -0.366781  0.499878  0.587424  1.126400  0.226270  ...  -0.845790
# 2018-10-28 -0.293084  0.390117  1.510660  1.697744  0.763678  ...   2.466582
# 2018-11-04 -0.143659  0.711931  0.341763  1.327545  2.180489  ...   1.421114
# 2018-11-11  0.157413  0.439923  1.391321  0.764717  1.569477  ...   0.669981
# 2018-11-18 -0.146766  0.492355  1.007562  0.105904  0.756730  ...   0.585881
# ...              ...       ...       ...       ...       ...  ...        ...
# 2023-06-18 -0.213863  0.416604 -0.008677 -0.588172 -0.323973  ...   1.336874
# 2023-06-25 -0.288077  0.255610  0.131101  1.020975 -1.333978  ...   0.231501
# 2023-07-02 -0.665095  0.148148 -0.515546  0.077819  0.086884  ...   0.900784
# 2023-07-09 -0.436072 -0.067422 -0.641025 -0.487896 -0.789235  ...   0.756642
# 2023-07-16  0.322392 -0.066359  0.409302 -1.903118  0.159507  ...   0.688078
#
#                  uae     truck       suv       war    unrest  groundwater  \
# Timestamp
# 2018-10-21  2.133580 -1.549842 -0.895158  0.686088 -0.421696     0.613868
# 2018-10-28 -0.423657 -0.372133  0.005122  0.681242 -1.526335     0.332409
# 2018-11-04  0.222541  1.306740  1.105534  1.261611 -4.143893     1.813575
# 2018-11-11 -0.238344  0.311918  0.909245 -0.429977 -0.258794     0.327042
# 2018-11-18  2.092351  0.328152 -0.481567 -1.240620  0.068309     0.139372
# ...              ...       ...       ...       ...       ...          ...
# 2023-06-18  0.316314 -1.319625  0.583327  0.118758  0.175372     0.031403
# 2023-06-25 -0.788674  0.186280  0.182788 -0.761709  0.336458    -1.168575
# 2023-07-02 -0.089718  0.355198 -0.020388 -1.934703  0.088712    -1.256105
# 2023-07-09 -0.380343  0.524001  0.574915 -0.910005 -4.044054    -0.415569
# 2023-07-16  0.262547 -0.308462 -0.724756 -0.690538 -0.938246     0.054367
#
#                 gulf   utility      Diff
# Timestamp
# 2018-10-21 -0.401372 -0.694890  0.017040
# 2018-10-28 -0.024471  0.171016  0.005704
# 2018-11-04  0.054427  2.007549  0.010659
# 2018-11-11  0.207467  0.278819  0.004828
# 2018-11-18  0.062400  0.711572  0.009515
# ...              ...       ...       ...
# 2023-06-18 -0.532608 -0.680540  0.020767
# 2023-06-25 -4.566537  0.944740  0.003419
# 2023-07-02 -1.351841 -0.022000 -0.035035
# 2023-07-09 -0.074501 -0.127088  0.001202
# 2023-07-16  0.154404 -0.229087 -0.001443
#
# [248 rows x 189 columns]

# %% [markdown]
# This is the Keras NN model. I estimate the best one with trial and error. Since I am outing on a tanh activation, I am also calculating the tanh of the response variable (previous step).

# %%
#initialize
neur = tf.keras.models.Sequential()
#layers
neur.add(tf.keras.layers.Dense(units=1000, activation='tanh'))
neur.add(tf.keras.layers.Dense(units=5000, activation='tanh'))
neur.add(tf.keras.layers.Dense(units=7000, activation='tanh'))

#output layer
neur.add(tf.keras.layers.Dense(units=1))

from keras import backend as K
def custom_metric(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

#using mse for regression. Simple and clear
neur.compile(optimizer='Adam', loss='mean_squared_error', metrics=[custom_metric])

#train
neur.fit(x_subset, y_subset, batch_size=220, epochs=2000)
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 6s 691ms/step - loss: 40.3693 - custom_metric: -961797.6875
# Epoch 2/2000
# 2/2 [==============================] - 3s 667ms/step - loss: 482.1231 - custom_metric: -534075.6875
# Epoch 3/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 84.6802 - custom_metric: -127462.3281
# Epoch 4/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 135.9065 - custom_metric: -178293.9688
# Epoch 5/2000
# 2/2 [==============================] - 4s 1s/step - loss: 80.7488 - custom_metric: -222756.9219
# Epoch 6/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 41.9976 - custom_metric: -55160.1406
# Epoch 7/2000
# 2/2 [==============================] - 3s 739ms/step - loss: 27.9182 - custom_metric: -31683.6543
# Epoch 8/2000
# 2/2 [==============================] - 3s 657ms/step - loss: 9.3396 - custom_metric: -12097.5752
# Epoch 9/2000
# 2/2 [==============================] - 2s 653ms/step - loss: 11.0402 - custom_metric: -46758.9844
# Epoch 10/2000
# 2/2 [==============================] - 4s 2s/step - loss: 14.6753 - custom_metric: -61232.6797
# Epoch 11/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 15.6276 - custom_metric: -33301.9531
# Epoch 12/2000
# 2/2 [==============================] - 3s 648ms/step - loss: 10.1349 - custom_metric: -118719.9141
# Epoch 13/2000
# 2/2 [==============================] - 3s 712ms/step - loss: 6.6857 - custom_metric: -26836.3359
# Epoch 14/2000
# 2/2 [==============================] - 4s 1s/step - loss: 4.7029 - custom_metric: -16589.0254
# Epoch 15/2000
# 2/2 [==============================] - 3s 680ms/step - loss: 2.0650 - custom_metric: -4635.4980
# Epoch 16/2000
# 2/2 [==============================] - 3s 656ms/step - loss: 1.7566 - custom_metric: -4394.1240
# Epoch 17/2000
# 2/2 [==============================] - 5s 2s/step - loss: 2.2361 - custom_metric: -8909.4131
# Epoch 18/2000
# 2/2 [==============================] - 4s 681ms/step - loss: 1.6072 - custom_metric: -2133.2437
# Epoch 19/2000
# 2/2 [==============================] - 2s 676ms/step - loss: 1.1644 - custom_metric: -1536.3430
# Epoch 20/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 1.5058 - custom_metric: -3556.0537
# Epoch 21/2000
# 2/2 [==============================] - 3s 708ms/step - loss: 1.4510 - custom_metric: -3126.6536
# Epoch 22/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.9410 - custom_metric: -2759.7124
# Epoch 23/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.8666 - custom_metric: -1151.5454
# Epoch 24/2000
# 2/2 [==============================] - 3s 660ms/step - loss: 0.7625 - custom_metric: -3836.1548
# Epoch 25/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.4092 - custom_metric: -1131.3379
# Epoch 26/2000
# 2/2 [==============================] - 3s 723ms/step - loss: 0.3050 - custom_metric: -1171.2952
# Epoch 27/2000
# 2/2 [==============================] - 7s 3s/step - loss: 0.3081 - custom_metric: -1845.1433
# Epoch 28/2000
# 2/2 [==============================] - 6s 2s/step - loss: 0.1855 - custom_metric: -754.5435
# Epoch 29/2000
# 2/2 [==============================] - 6s 2s/step - loss: 0.1600 - custom_metric: -499.3045
# Epoch 30/2000
# 2/2 [==============================] - 3s 686ms/step - loss: 0.1948 - custom_metric: -1359.4302
# Epoch 31/2000
# 2/2 [==============================] - 3s 742ms/step - loss: 0.1285 - custom_metric: -374.7304
# Epoch 32/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.1052 - custom_metric: -421.3270
# Epoch 33/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.1229 - custom_metric: -153.2516
# Epoch 34/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 0.0835 - custom_metric: -154.5786
# Epoch 35/2000
# 2/2 [==============================] - 3s 682ms/step - loss: 0.0705 - custom_metric: -93.7483
# Epoch 36/2000
# 2/2 [==============================] - 3s 696ms/step - loss: 0.0902 - custom_metric: -117.0715
# Epoch 37/2000
# 2/2 [==============================] - 3s 653ms/step - loss: 0.0624 - custom_metric: -64.6126
# Epoch 38/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0504 - custom_metric: -224.1672
# Epoch 39/2000
# 2/2 [==============================] - 3s 673ms/step - loss: 0.0668 - custom_metric: -73.9875
# Epoch 40/2000
# 2/2 [==============================] - 2s 688ms/step - loss: 0.0472 - custom_metric: -66.6267
# Epoch 41/2000
# 2/2 [==============================] - 3s 707ms/step - loss: 0.0297 - custom_metric: -56.5721
# Epoch 42/2000
# 2/2 [==============================] - 3s 789ms/step - loss: 0.0377 - custom_metric: -132.1540
# Epoch 43/2000
# 2/2 [==============================] - 4s 693ms/step - loss: 0.0261 - custom_metric: -52.8451
# Epoch 44/2000
# 2/2 [==============================] - 3s 702ms/step - loss: 0.0238 - custom_metric: -99.6163
# Epoch 45/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 0.0334 - custom_metric: -60.9276
# Epoch 46/2000
# 2/2 [==============================] - 3s 719ms/step - loss: 0.0228 - custom_metric: -42.3776
# Epoch 47/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0246 - custom_metric: -43.5041
# Epoch 48/2000
# 2/2 [==============================] - 3s 741ms/step - loss: 0.0269 - custom_metric: -31.3836
# Epoch 49/2000
# 2/2 [==============================] - 3s 721ms/step - loss: 0.0174 - custom_metric: -60.8546
# Epoch 50/2000
# 2/2 [==============================] - 3s 691ms/step - loss: 0.0185 - custom_metric: -23.8588
# Epoch 51/2000
# 2/2 [==============================] - 3s 717ms/step - loss: 0.0185 - custom_metric: -41.3081
# Epoch 52/2000
# 2/2 [==============================] - 4s 773ms/step - loss: 0.0132 - custom_metric: -46.5630
# Epoch 53/2000
# 2/2 [==============================] - 3s 697ms/step - loss: 0.0153 - custom_metric: -27.8315
# Epoch 54/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 0.0148 - custom_metric: -37.5590
# Epoch 55/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 0.0125 - custom_metric: -16.6174
# Epoch 56/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0129 - custom_metric: -21.6143
# Epoch 57/2000
# 2/2 [==============================] - 3s 672ms/step - loss: 0.0110 - custom_metric: -78.5580
# Epoch 58/2000
# 2/2 [==============================] - 3s 712ms/step - loss: 0.0106 - custom_metric: -29.0473
# Epoch 59/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 0.0106 - custom_metric: -10.9408
# Epoch 60/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.0102 - custom_metric: -13.3267
# Epoch 61/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0102 - custom_metric: -49.4442
# Epoch 62/2000
# 2/2 [==============================] - 3s 698ms/step - loss: 0.0100 - custom_metric: -12.8993
# Epoch 63/2000
# 2/2 [==============================] - 3s 662ms/step - loss: 0.0105 - custom_metric: -13.4637
# Epoch 64/2000
# 2/2 [==============================] - 3s 727ms/step - loss: 0.0101 - custom_metric: -14.3369
# Epoch 65/2000
# 2/2 [==============================] - 3s 845ms/step - loss: 0.0089 - custom_metric: -23.2009
# Epoch 66/2000
# 2/2 [==============================] - 4s 683ms/step - loss: 0.0098 - custom_metric: -43.2948
# Epoch 67/2000
# 2/2 [==============================] - 3s 647ms/step - loss: 0.0099 - custom_metric: -12.6389
# Epoch 68/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 0.0091 - custom_metric: -17.6851
# Epoch 69/2000
# 2/2 [==============================] - 3s 666ms/step - loss: 0.0085 - custom_metric: -33.8329
# Epoch 70/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0083 - custom_metric: -31.3442
# Epoch 71/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 0.0086 - custom_metric: -13.3762
# Epoch 72/2000
# 2/2 [==============================] - 3s 698ms/step - loss: 0.0076 - custom_metric: -42.8590
# Epoch 73/2000
# 2/2 [==============================] - 3s 677ms/step - loss: 0.0076 - custom_metric: -25.2415
# Epoch 74/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.0075 - custom_metric: -38.8503
# Epoch 75/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0069 - custom_metric: -13.0803
# Epoch 76/2000
# 2/2 [==============================] - 3s 700ms/step - loss: 0.0070 - custom_metric: -16.7445
# Epoch 77/2000
# 2/2 [==============================] - 3s 666ms/step - loss: 0.0066 - custom_metric: -31.1361
# Epoch 78/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 0.0069 - custom_metric: -13.7411
# Epoch 79/2000
# 2/2 [==============================] - 3s 817ms/step - loss: 0.0069 - custom_metric: -26.6659
# Epoch 80/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 0.0069 - custom_metric: -14.6156
# Epoch 81/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 0.0060 - custom_metric: -19.1149
# Epoch 82/2000
# 2/2 [==============================] - 3s 696ms/step - loss: 0.0062 - custom_metric: -8.4461
# Epoch 83/2000
# 2/2 [==============================] - 3s 662ms/step - loss: 0.0062 - custom_metric: -54.8482
# Epoch 84/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0058 - custom_metric: -7.9774
# Epoch 85/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 0.0059 - custom_metric: -10.2665
# Epoch 86/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 0.0059 - custom_metric: -23.7323
# Epoch 87/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.0056 - custom_metric: -30.1542
# Epoch 88/2000
# 2/2 [==============================] - 3s 676ms/step - loss: 0.0050 - custom_metric: -11.6142
# Epoch 89/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0057 - custom_metric: -37.5957
# Epoch 90/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 0.0056 - custom_metric: -14.4626
# Epoch 91/2000
# 2/2 [==============================] - 3s 759ms/step - loss: 0.0049 - custom_metric: -13.4686
# Epoch 92/2000
# 2/2 [==============================] - 3s 700ms/step - loss: 0.0049 - custom_metric: -14.6021
# Epoch 93/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0051 - custom_metric: -4.8863
# Epoch 94/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 0.0048 - custom_metric: -5.4166
# Epoch 95/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 0.0052 - custom_metric: -12.9021
# Epoch 96/2000
# 2/2 [==============================] - 3s 706ms/step - loss: 0.0051 - custom_metric: -21.9338
# Epoch 97/2000
# 2/2 [==============================] - 3s 709ms/step - loss: 0.0045 - custom_metric: -12.0657
# Epoch 98/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0050 - custom_metric: -24.7690
# Epoch 99/2000
# 2/2 [==============================] - 3s 687ms/step - loss: 0.0045 - custom_metric: -5.1002
# Epoch 100/2000
# 2/2 [==============================] - 3s 715ms/step - loss: 0.0043 - custom_metric: -14.5255
# Epoch 101/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 0.0041 - custom_metric: -19.7461
# Epoch 102/2000
# 2/2 [==============================] - 3s 790ms/step - loss: 0.0044 - custom_metric: -5.0827
# Epoch 103/2000
# 2/2 [==============================] - 4s 663ms/step - loss: 0.0039 - custom_metric: -8.6215
# Epoch 104/2000
# 2/2 [==============================] - 3s 713ms/step - loss: 0.0041 - custom_metric: -39.0737
# Epoch 105/2000
# 2/2 [==============================] - 3s 700ms/step - loss: 0.0047 - custom_metric: -16.3504
# Epoch 106/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 0.0039 - custom_metric: -15.4033
# Epoch 107/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0041 - custom_metric: -12.9355
# Epoch 108/2000
# 2/2 [==============================] - 3s 713ms/step - loss: 0.0039 - custom_metric: -7.3382
# Epoch 109/2000
# 2/2 [==============================] - 3s 722ms/step - loss: 0.0038 - custom_metric: -12.3249
# Epoch 110/2000
# 2/2 [==============================] - 3s 705ms/step - loss: 0.0034 - custom_metric: -18.4685
# Epoch 111/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0035 - custom_metric: -3.7912
# Epoch 112/2000
# 2/2 [==============================] - 4s 978ms/step - loss: 0.0037 - custom_metric: -16.1108
# Epoch 113/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 0.0034 - custom_metric: -4.5919
# Epoch 114/2000
# 2/2 [==============================] - 3s 670ms/step - loss: 0.0034 - custom_metric: -3.3714
# Epoch 115/2000
# 2/2 [==============================] - 3s 649ms/step - loss: 0.0033 - custom_metric: -12.2187
# Epoch 116/2000
# 2/2 [==============================] - 3s 859ms/step - loss: 0.0033 - custom_metric: -10.9419
# Epoch 117/2000
# 2/2 [==============================] - 4s 665ms/step - loss: 0.0032 - custom_metric: -12.2631
# Epoch 118/2000
# 2/2 [==============================] - 3s 686ms/step - loss: 0.0031 - custom_metric: -14.5804
# Epoch 119/2000
# 2/2 [==============================] - 3s 661ms/step - loss: 0.0030 - custom_metric: -7.4909
# Epoch 120/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 0.0029 - custom_metric: -2.4959
# Epoch 121/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0029 - custom_metric: -7.5008
# Epoch 122/2000
# 2/2 [==============================] - 3s 737ms/step - loss: 0.0029 - custom_metric: -3.1829
# Epoch 123/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 0.0030 - custom_metric: -13.5769
# Epoch 124/2000
# 2/2 [==============================] - 3s 714ms/step - loss: 0.0028 - custom_metric: -4.1377
# Epoch 125/2000
# 2/2 [==============================] - 3s 680ms/step - loss: 0.0030 - custom_metric: -9.7135
# Epoch 126/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0028 - custom_metric: -2.8328
# Epoch 127/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0027 - custom_metric: -5.8623
# Epoch 128/2000
# 2/2 [==============================] - 3s 726ms/step - loss: 0.0028 - custom_metric: -8.2506
# Epoch 129/2000
# 2/2 [==============================] - 3s 665ms/step - loss: 0.0027 - custom_metric: -18.3288
# Epoch 130/2000
# 2/2 [==============================] - 3s 939ms/step - loss: 0.0029 - custom_metric: -2.2888
# Epoch 131/2000
# 2/2 [==============================] - 3s 731ms/step - loss: 0.0027 - custom_metric: -11.7302
# Epoch 132/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0026 - custom_metric: -2.6286
# Epoch 133/2000
# 2/2 [==============================] - 2s 683ms/step - loss: 0.0024 - custom_metric: -1.9282
# Epoch 134/2000
# 2/2 [==============================] - 3s 719ms/step - loss: 0.0024 - custom_metric: -2.4952
# Epoch 135/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0023 - custom_metric: -6.9422
# Epoch 136/2000
# 2/2 [==============================] - 3s 670ms/step - loss: 0.0024 - custom_metric: -2.3057
# Epoch 137/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.0025 - custom_metric: -18.2068
# Epoch 138/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0025 - custom_metric: -1.7811
# Epoch 139/2000
# 2/2 [==============================] - 2s 684ms/step - loss: 0.0025 - custom_metric: -2.0952
# Epoch 140/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0026 - custom_metric: -3.2380
# Epoch 141/2000
# 2/2 [==============================] - 3s 667ms/step - loss: 0.0024 - custom_metric: -1.8681
# Epoch 142/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.0022 - custom_metric: -9.5910
# Epoch 143/2000
# 2/2 [==============================] - 3s 700ms/step - loss: 0.0023 - custom_metric: -12.7098
# Epoch 144/2000
# 2/2 [==============================] - 3s 835ms/step - loss: 0.0022 - custom_metric: -7.9791
# Epoch 145/2000
# 2/2 [==============================] - 4s 744ms/step - loss: 0.0023 - custom_metric: -2.7747
# Epoch 146/2000
# 2/2 [==============================] - 3s 656ms/step - loss: 0.0021 - custom_metric: -2.0295
# Epoch 147/2000
# 2/2 [==============================] - 3s 663ms/step - loss: 0.0022 - custom_metric: -1.9202
# Epoch 148/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.0023 - custom_metric: -6.8865
# Epoch 149/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0023 - custom_metric: -7.9947
# Epoch 150/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 0.0023 - custom_metric: -4.8367
# Epoch 151/2000
# 2/2 [==============================] - 3s 660ms/step - loss: 0.0021 - custom_metric: -2.1844
# Epoch 152/2000
# 2/2 [==============================] - 3s 673ms/step - loss: 0.0022 - custom_metric: -7.3159
# Epoch 153/2000
# 2/2 [==============================] - 3s 673ms/step - loss: 0.0020 - custom_metric: -2.2234
# Epoch 154/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0023 - custom_metric: -11.4356
# Epoch 155/2000
# 2/2 [==============================] - 3s 652ms/step - loss: 0.0022 - custom_metric: -1.9812
# Epoch 156/2000
# 2/2 [==============================] - 3s 676ms/step - loss: 0.0021 - custom_metric: -5.1131
# Epoch 157/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 0.0020 - custom_metric: -5.3583
# Epoch 158/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 0.0024 - custom_metric: -3.0341
# Epoch 159/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0022 - custom_metric: -6.7408
# Epoch 160/2000
# 2/2 [==============================] - 3s 674ms/step - loss: 0.0021 - custom_metric: -4.4744
# Epoch 161/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 0.0019 - custom_metric: -1.2803
# Epoch 162/2000
# 2/2 [==============================] - 3s 654ms/step - loss: 0.0018 - custom_metric: -2.0385
# Epoch 163/2000
# 2/2 [==============================] - 3s 821ms/step - loss: 0.0020 - custom_metric: -3.2458
# Epoch 164/2000
# 2/2 [==============================] - 3s 668ms/step - loss: 0.0018 - custom_metric: -6.5693
# Epoch 165/2000
# 2/2 [==============================] - 3s 706ms/step - loss: 0.0019 - custom_metric: -2.2386
# Epoch 166/2000
# 2/2 [==============================] - 3s 649ms/step - loss: 0.0019 - custom_metric: -1.5103
# Epoch 167/2000
# 2/2 [==============================] - 2s 657ms/step - loss: 0.0021 - custom_metric: -1.9150
# Epoch 168/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0019 - custom_metric: -1.3585
# Epoch 169/2000
# 2/2 [==============================] - 3s 677ms/step - loss: 0.0019 - custom_metric: -2.5667
# Epoch 170/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 0.0017 - custom_metric: -6.7837
# Epoch 171/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 0.0021 - custom_metric: -2.1091
# Epoch 172/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 0.0019 - custom_metric: -1.3756
# Epoch 173/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0018 - custom_metric: -3.1401
# Epoch 174/2000
# 2/2 [==============================] - 3s 649ms/step - loss: 0.0018 - custom_metric: -7.2555
# Epoch 175/2000
# 2/2 [==============================] - 2s 644ms/step - loss: 0.0017 - custom_metric: -2.2195
# Epoch 176/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.0018 - custom_metric: -14.5921
# Epoch 177/2000
# 2/2 [==============================] - 3s 659ms/step - loss: 0.0016 - custom_metric: -2.0840
# Epoch 178/2000
# 2/2 [==============================] - 4s 836ms/step - loss: 0.0017 - custom_metric: -2.0732
# Epoch 179/2000
# 2/2 [==============================] - 3s 669ms/step - loss: 0.0017 - custom_metric: -2.2112
# Epoch 180/2000
# 2/2 [==============================] - 3s 729ms/step - loss: 0.0016 - custom_metric: -1.0516
# Epoch 181/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 0.0016 - custom_metric: -4.4411
# Epoch 182/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0017 - custom_metric: -5.0396
# Epoch 183/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0016 - custom_metric: -3.8766
# Epoch 184/2000
# 2/2 [==============================] - 3s 669ms/step - loss: 0.0017 - custom_metric: -9.6081
# Epoch 185/2000
# 2/2 [==============================] - 3s 677ms/step - loss: 0.0017 - custom_metric: -4.5451
# Epoch 186/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.0016 - custom_metric: -4.9272
# Epoch 187/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0017 - custom_metric: -1.4205
# Epoch 188/2000
# 2/2 [==============================] - 3s 653ms/step - loss: 0.0015 - custom_metric: -1.1786
# Epoch 189/2000
# 2/2 [==============================] - 3s 670ms/step - loss: 0.0015 - custom_metric: -1.2261
# Epoch 190/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 0.0016 - custom_metric: -10.0992
# Epoch 191/2000
# 2/2 [==============================] - 3s 684ms/step - loss: 0.0016 - custom_metric: -2.1888
# Epoch 192/2000
# 2/2 [==============================] - 4s 823ms/step - loss: 0.0017 - custom_metric: -2.1572
# Epoch 193/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 0.0016 - custom_metric: -2.0970
# Epoch 194/2000
# 2/2 [==============================] - 3s 668ms/step - loss: 0.0015 - custom_metric: -1.5220
# Epoch 195/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 0.0014 - custom_metric: -0.9225
# Epoch 196/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0015 - custom_metric: -1.0897
# Epoch 197/2000
# 2/2 [==============================] - 3s 680ms/step - loss: 0.0015 - custom_metric: -6.0991
# Epoch 198/2000
# 2/2 [==============================] - 3s 667ms/step - loss: 0.0017 - custom_metric: -0.8700
# Epoch 199/2000
# 2/2 [==============================] - 3s 696ms/step - loss: 0.0015 - custom_metric: -1.0345
# Epoch 200/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.0014 - custom_metric: -2.3993
# Epoch 201/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0015 - custom_metric: -9.8815
# Epoch 202/2000
# 2/2 [==============================] - 3s 708ms/step - loss: 0.0014 - custom_metric: -1.2853
# Epoch 203/2000
# 2/2 [==============================] - 3s 677ms/step - loss: 0.0014 - custom_metric: -5.5495
# Epoch 204/2000
# 2/2 [==============================] - 3s 702ms/step - loss: 0.0014 - custom_metric: -3.4804
# Epoch 205/2000
# 2/2 [==============================] - 3s 659ms/step - loss: 0.0014 - custom_metric: -4.0560
# Epoch 206/2000
# 2/2 [==============================] - 4s 804ms/step - loss: 0.0014 - custom_metric: -0.6603
# Epoch 207/2000
# 2/2 [==============================] - 3s 680ms/step - loss: 0.0016 - custom_metric: -0.9759
# Epoch 208/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 0.0014 - custom_metric: -1.1800
# Epoch 209/2000
# 2/2 [==============================] - 3s 654ms/step - loss: 0.0014 - custom_metric: -0.8317
# Epoch 210/2000
# 2/2 [==============================] - 3s 950ms/step - loss: 0.0014 - custom_metric: -3.9220
# Epoch 211/2000
# 2/2 [==============================] - 3s 718ms/step - loss: 0.0014 - custom_metric: -3.0733
# Epoch 212/2000
# 2/2 [==============================] - 3s 658ms/step - loss: 0.0013 - custom_metric: -0.6473
# Epoch 213/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0014 - custom_metric: -3.7186
# Epoch 214/2000
# 2/2 [==============================] - 3s 665ms/step - loss: 0.0013 - custom_metric: -2.2673
# Epoch 215/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0013 - custom_metric: -2.4721
# Epoch 216/2000
# 2/2 [==============================] - 4s 867ms/step - loss: 0.0013 - custom_metric: -0.9049
# Epoch 217/2000
# 2/2 [==============================] - 2s 653ms/step - loss: 0.0013 - custom_metric: -0.6177
# Epoch 218/2000
# 2/2 [==============================] - 3s 687ms/step - loss: 0.0012 - custom_metric: -0.6625
# Epoch 219/2000
# 2/2 [==============================] - 3s 722ms/step - loss: 0.0013 - custom_metric: -0.5461
# Epoch 220/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0013 - custom_metric: -0.8141
# Epoch 221/2000
# 2/2 [==============================] - 3s 665ms/step - loss: 0.0012 - custom_metric: -0.5635
# Epoch 222/2000
# 2/2 [==============================] - 3s 655ms/step - loss: 0.0012 - custom_metric: -7.8994
# Epoch 223/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 0.0013 - custom_metric: -0.8046
# Epoch 224/2000
# 2/2 [==============================] - 3s 663ms/step - loss: 0.0015 - custom_metric: -6.9326
# Epoch 225/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0012 - custom_metric: -0.7744
# Epoch 226/2000
# 2/2 [==============================] - 3s 660ms/step - loss: 0.0015 - custom_metric: -1.4837
# Epoch 227/2000
# 2/2 [==============================] - 2s 655ms/step - loss: 0.0017 - custom_metric: -1.0612
# Epoch 228/2000
# 2/2 [==============================] - 3s 668ms/step - loss: 0.0013 - custom_metric: -1.4903
# Epoch 229/2000
# 2/2 [==============================] - 3s 670ms/step - loss: 0.0015 - custom_metric: -2.2783
# Epoch 230/2000
# 2/2 [==============================] - 4s 738ms/step - loss: 0.0016 - custom_metric: -2.2346
# Epoch 231/2000
# 2/2 [==============================] - 2s 659ms/step - loss: 0.0014 - custom_metric: -1.0685
# Epoch 232/2000
# 2/2 [==============================] - 3s 673ms/step - loss: 0.0015 - custom_metric: -1.5276
# Epoch 233/2000
# 2/2 [==============================] - 3s 703ms/step - loss: 0.0013 - custom_metric: -0.8014
# Epoch 234/2000
# 2/2 [==============================] - 3s 942ms/step - loss: 0.0013 - custom_metric: -0.7762
# Epoch 235/2000
# 2/2 [==============================] - 3s 676ms/step - loss: 0.0014 - custom_metric: -3.6346
# Epoch 236/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 0.0012 - custom_metric: -7.0069
# Epoch 237/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0013 - custom_metric: -3.1256
# Epoch 238/2000
# 2/2 [==============================] - 3s 651ms/step - loss: 0.0012 - custom_metric: -0.5307
# Epoch 239/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0013 - custom_metric: -4.6484
# Epoch 240/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 0.0013 - custom_metric: -2.4864
# Epoch 241/2000
# 2/2 [==============================] - 3s 2s/step - loss: 0.0013 - custom_metric: -0.6130
# Epoch 242/2000
# 2/2 [==============================] - 7s 3s/step - loss: 0.0015 - custom_metric: -1.9550
# Epoch 243/2000
# 2/2 [==============================] - 6s 776ms/step - loss: 0.0012 - custom_metric: -0.7057
# Epoch 244/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 0.0013 - custom_metric: -3.0542
# Epoch 245/2000
# 2/2 [==============================] - 3s 667ms/step - loss: 0.0012 - custom_metric: -11.5927
# Epoch 246/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0012 - custom_metric: -0.6299
# Epoch 247/2000
# 2/2 [==============================] - 3s 650ms/step - loss: 0.0012 - custom_metric: -1.0837
# Epoch 248/2000
# 2/2 [==============================] - 3s 680ms/step - loss: 0.0011 - custom_metric: -0.5820
# Epoch 249/2000
# 2/2 [==============================] - 3s 653ms/step - loss: 0.0012 - custom_metric: -2.1317
# Epoch 250/2000
# 2/2 [==============================] - 3s 674ms/step - loss: 0.0011 - custom_metric: -4.0711
# Epoch 251/2000
# 2/2 [==============================] - 3s 987ms/step - loss: 0.0011 - custom_metric: -0.4482
# Epoch 252/2000
# 2/2 [==============================] - 3s 677ms/step - loss: 0.0011 - custom_metric: -0.5669
# Epoch 253/2000
# 2/2 [==============================] - 3s 672ms/step - loss: 0.0011 - custom_metric: -3.3749
# Epoch 254/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 0.0012 - custom_metric: -0.9115
# Epoch 255/2000
# 2/2 [==============================] - 2s 679ms/step - loss: 0.0012 - custom_metric: -4.8648
# Epoch 256/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0011 - custom_metric: -1.6353
# Epoch 257/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 0.0011 - custom_metric: -2.2796
# Epoch 258/2000
# 2/2 [==============================] - 3s 682ms/step - loss: 0.0011 - custom_metric: -4.0216
# Epoch 259/2000
# 2/2 [==============================] - 3s 667ms/step - loss: 0.0011 - custom_metric: -3.7572
# Epoch 260/2000
# 2/2 [==============================] - 3s 933ms/step - loss: 0.0011 - custom_metric: -0.6270
# Epoch 261/2000
# 2/2 [==============================] - 3s 661ms/step - loss: 0.0011 - custom_metric: -0.9034
# Epoch 262/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0011 - custom_metric: -0.4829
# Epoch 263/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 0.0010 - custom_metric: -0.7583
# Epoch 264/2000
# 2/2 [==============================] - 3s 665ms/step - loss: 0.0011 - custom_metric: -0.4207
# Epoch 265/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0011 - custom_metric: -0.8993
# Epoch 266/2000
# 2/2 [==============================] - 3s 666ms/step - loss: 0.0010 - custom_metric: -3.1401
# Epoch 267/2000
# 2/2 [==============================] - 3s 719ms/step - loss: 0.0012 - custom_metric: -0.5991
# Epoch 268/2000
# 2/2 [==============================] - 3s 670ms/step - loss: 0.0011 - custom_metric: -0.5077
# Epoch 269/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.0010 - custom_metric: -0.3129
# Epoch 270/2000
# 2/2 [==============================] - 4s 1s/step - loss: 9.9894e-04 - custom_metric: -1.6489
# Epoch 271/2000
# 2/2 [==============================] - 3s 705ms/step - loss: 9.8933e-04 - custom_metric: -0.4441
# Epoch 272/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 0.0010 - custom_metric: -1.1999
# Epoch 273/2000
# 2/2 [==============================] - 2s 696ms/step - loss: 0.0011 - custom_metric: -1.0329
# Epoch 274/2000
# 2/2 [==============================] - 3s 874ms/step - loss: 0.0010 - custom_metric: -0.6606
# Epoch 275/2000
# 2/2 [==============================] - 4s 716ms/step - loss: 0.0011 - custom_metric: -2.2327
# Epoch 276/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 0.0010 - custom_metric: -0.9196
# Epoch 277/2000
# 2/2 [==============================] - 3s 731ms/step - loss: 0.0011 - custom_metric: -0.6352
# Epoch 278/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 0.0013 - custom_metric: -2.7303
# Epoch 279/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0011 - custom_metric: -2.3495
# Epoch 280/2000
# 2/2 [==============================] - 3s 669ms/step - loss: 0.0013 - custom_metric: -0.6603
# Epoch 281/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 0.0012 - custom_metric: -1.7502
# Epoch 282/2000
# 2/2 [==============================] - 3s 661ms/step - loss: 0.0011 - custom_metric: -1.3150
# Epoch 283/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 0.0011 - custom_metric: -2.3293
# Epoch 284/2000
# 2/2 [==============================] - 4s 1s/step - loss: 0.0010 - custom_metric: -2.2046
# Epoch 285/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 0.0012 - custom_metric: -0.7273
# Epoch 286/2000
# 2/2 [==============================] - 3s 677ms/step - loss: 0.0010 - custom_metric: -1.9657
# Epoch 287/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 0.0011 - custom_metric: -2.0248
# Epoch 288/2000
# 2/2 [==============================] - 3s 940ms/step - loss: 0.0010 - custom_metric: -2.0298
# Epoch 289/2000
# 2/2 [==============================] - 3s 653ms/step - loss: 9.6712e-04 - custom_metric: -1.6250
# Epoch 290/2000
# 2/2 [==============================] - 3s 706ms/step - loss: 9.7636e-04 - custom_metric: -0.5445
# Epoch 291/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 9.8436e-04 - custom_metric: -0.4212
# Epoch 292/2000
# 2/2 [==============================] - 3s 668ms/step - loss: 0.0010 - custom_metric: -0.3252
# Epoch 293/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0010 - custom_metric: -0.7237
# Epoch 294/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 9.7470e-04 - custom_metric: -0.3906
# Epoch 295/2000
# 2/2 [==============================] - 3s 672ms/step - loss: 0.0010 - custom_metric: -0.8304
# Epoch 296/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 9.2508e-04 - custom_metric: -0.2330
# Epoch 297/2000
# 2/2 [==============================] - 3s 672ms/step - loss: 9.6586e-04 - custom_metric: -1.6385
# Epoch 298/2000
# 2/2 [==============================] - 4s 973ms/step - loss: 0.0011 - custom_metric: -0.5691
# Epoch 299/2000
# 2/2 [==============================] - 3s 674ms/step - loss: 9.7079e-04 - custom_metric: -0.3415
# Epoch 300/2000
# 2/2 [==============================] - 3s 745ms/step - loss: 0.0010 - custom_metric: -2.1063
# Epoch 301/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 9.5518e-04 - custom_metric: -0.3556
# Epoch 302/2000
# 2/2 [==============================] - 3s 1s/step - loss: 9.9424e-04 - custom_metric: -2.2410
# Epoch 303/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 9.0118e-04 - custom_metric: -0.2921
# Epoch 304/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 8.9356e-04 - custom_metric: -1.6265
# Epoch 305/2000
# 2/2 [==============================] - 3s 673ms/step - loss: 0.0010 - custom_metric: -1.9427
# Epoch 306/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 9.4979e-04 - custom_metric: -0.3457
# Epoch 307/2000
# 2/2 [==============================] - 4s 1s/step - loss: 9.7429e-04 - custom_metric: -0.3768
# Epoch 308/2000
# 2/2 [==============================] - 3s 674ms/step - loss: 9.4961e-04 - custom_metric: -0.4806
# Epoch 309/2000
# 2/2 [==============================] - 3s 673ms/step - loss: 9.1733e-04 - custom_metric: -1.3307
# Epoch 310/2000
# 2/2 [==============================] - 2s 691ms/step - loss: 9.3484e-04 - custom_metric: -0.5160
# Epoch 311/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 8.8133e-04 - custom_metric: -0.1948
# Epoch 312/2000
# 2/2 [==============================] - 4s 821ms/step - loss: 9.1949e-04 - custom_metric: -1.0247
# Epoch 313/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 8.9334e-04 - custom_metric: -1.1004
# Epoch 314/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 8.5142e-04 - custom_metric: -3.1202
# Epoch 315/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 8.3718e-04 - custom_metric: -0.3776
# Epoch 316/2000
# 2/2 [==============================] - 3s 1s/step - loss: 8.3516e-04 - custom_metric: -1.4828
# Epoch 317/2000
# 2/2 [==============================] - 3s 693ms/step - loss: 8.2660e-04 - custom_metric: -0.1888
# Epoch 318/2000
# 2/2 [==============================] - 3s 734ms/step - loss: 8.7675e-04 - custom_metric: -0.6955
# Epoch 319/2000
# 2/2 [==============================] - 3s 664ms/step - loss: 8.5273e-04 - custom_metric: -0.1882
# Epoch 320/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 8.9211e-04 - custom_metric: -1.3200
# Epoch 321/2000
# 2/2 [==============================] - 4s 1s/step - loss: 9.0294e-04 - custom_metric: -4.1428
# Epoch 322/2000
# 2/2 [==============================] - 3s 709ms/step - loss: 9.3659e-04 - custom_metric: -1.2373
# Epoch 323/2000
# 2/2 [==============================] - 3s 661ms/step - loss: 8.8334e-04 - custom_metric: -0.6178
# Epoch 324/2000
# 2/2 [==============================] - 3s 693ms/step - loss: 8.6422e-04 - custom_metric: -3.3945
# Epoch 325/2000
# 2/2 [==============================] - 3s 717ms/step - loss: 8.4903e-04 - custom_metric: -0.4026
# Epoch 326/2000
# 2/2 [==============================] - 4s 691ms/step - loss: 8.6425e-04 - custom_metric: -0.1396
# Epoch 327/2000
# 2/2 [==============================] - 3s 697ms/step - loss: 8.1397e-04 - custom_metric: -0.1613
# Epoch 328/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 8.5267e-04 - custom_metric: -0.2084
# Epoch 329/2000
# 2/2 [==============================] - 3s 682ms/step - loss: 8.5232e-04 - custom_metric: -0.1674
# Epoch 330/2000
# 2/2 [==============================] - 3s 1s/step - loss: 8.1785e-04 - custom_metric: -0.6954
# Epoch 331/2000
# 2/2 [==============================] - 3s 673ms/step - loss: 8.6735e-04 - custom_metric: -0.9058
# Epoch 332/2000
# 2/2 [==============================] - 2s 674ms/step - loss: 7.8730e-04 - custom_metric: -0.2018
# Epoch 333/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 8.0011e-04 - custom_metric: 0.0115
# Epoch 334/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 8.2155e-04 - custom_metric: -0.0548
# Epoch 335/2000
# 2/2 [==============================] - 4s 1s/step - loss: 7.7830e-04 - custom_metric: -0.0425
# Epoch 336/2000
# 2/2 [==============================] - 3s 667ms/step - loss: 7.8790e-04 - custom_metric: -0.0101
# Epoch 337/2000
# 2/2 [==============================] - 3s 667ms/step - loss: 8.0401e-04 - custom_metric: -0.1380
# Epoch 338/2000
# 2/2 [==============================] - 3s 685ms/step - loss: 7.9378e-04 - custom_metric: -0.1428
# Epoch 339/2000
# 2/2 [==============================] - 3s 697ms/step - loss: 8.6586e-04 - custom_metric: -1.4814
# Epoch 340/2000
# 2/2 [==============================] - 4s 716ms/step - loss: 7.9815e-04 - custom_metric: -0.0964
# Epoch 341/2000
# 2/2 [==============================] - 3s 674ms/step - loss: 8.3792e-04 - custom_metric: -0.2949
# Epoch 342/2000
# 2/2 [==============================] - 3s 687ms/step - loss: 8.4017e-04 - custom_metric: -0.5262
# Epoch 343/2000
# 2/2 [==============================] - 3s 684ms/step - loss: 8.1551e-04 - custom_metric: -0.1547
# Epoch 344/2000
# 2/2 [==============================] - 3s 1s/step - loss: 8.1066e-04 - custom_metric: -0.2068
# Epoch 345/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 7.9800e-04 - custom_metric: 0.0293
# Epoch 346/2000
# 2/2 [==============================] - 3s 663ms/step - loss: 8.4201e-04 - custom_metric: -0.2874
# Epoch 347/2000
# 2/2 [==============================] - 2s 648ms/step - loss: 7.9116e-04 - custom_metric: -0.1098
# Epoch 348/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 8.5218e-04 - custom_metric: -0.1812
# Epoch 349/2000
# 2/2 [==============================] - 4s 1s/step - loss: 7.7629e-04 - custom_metric: -0.7867
# Epoch 350/2000
# 2/2 [==============================] - 3s 723ms/step - loss: 7.8604e-04 - custom_metric: 0.1127
# Epoch 351/2000
# 2/2 [==============================] - 3s 665ms/step - loss: 7.9905e-04 - custom_metric: -0.0912
# Epoch 352/2000
# 2/2 [==============================] - 3s 687ms/step - loss: 7.7035e-04 - custom_metric: -0.1197
# Epoch 353/2000
# 2/2 [==============================] - 3s 906ms/step - loss: 7.8312e-04 - custom_metric: -0.5475
# Epoch 354/2000
# 2/2 [==============================] - 4s 709ms/step - loss: 7.7903e-04 - custom_metric: -0.1278
# Epoch 355/2000
# 2/2 [==============================] - 3s 654ms/step - loss: 7.7183e-04 - custom_metric: -0.4681
# Epoch 356/2000
# 2/2 [==============================] - 3s 756ms/step - loss: 7.7837e-04 - custom_metric: -0.1887
# Epoch 357/2000
# 2/2 [==============================] - 3s 686ms/step - loss: 7.5576e-04 - custom_metric: 0.0195
# Epoch 358/2000
# 2/2 [==============================] - 4s 1s/step - loss: 7.4680e-04 - custom_metric: -0.5843
# Epoch 359/2000
# 2/2 [==============================] - 3s 711ms/step - loss: 7.4033e-04 - custom_metric: -0.1295
# Epoch 360/2000
# 2/2 [==============================] - 3s 721ms/step - loss: 7.4237e-04 - custom_metric: -2.9698
# Epoch 361/2000
# 2/2 [==============================] - 3s 720ms/step - loss: 8.1577e-04 - custom_metric: -0.5150
# Epoch 362/2000
# 2/2 [==============================] - 3s 987ms/step - loss: 7.5742e-04 - custom_metric: -0.1389
# Epoch 363/2000
# 2/2 [==============================] - 3s 720ms/step - loss: 8.0806e-04 - custom_metric: -0.5120
# Epoch 364/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 7.9634e-04 - custom_metric: -0.1496
# Epoch 365/2000
# 2/2 [==============================] - 3s 730ms/step - loss: 7.8962e-04 - custom_metric: -2.2438
# Epoch 366/2000
# 2/2 [==============================] - 3s 751ms/step - loss: 7.7933e-04 - custom_metric: -0.8261
# Epoch 367/2000
# 2/2 [==============================] - 3s 682ms/step - loss: 7.5985e-04 - custom_metric: -0.7593
# Epoch 368/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 8.4345e-04 - custom_metric: -0.2572
# Epoch 369/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 7.4192e-04 - custom_metric: -0.1606
# Epoch 370/2000
# 2/2 [==============================] - 3s 705ms/step - loss: 7.7880e-04 - custom_metric: -0.5838
# Epoch 371/2000
# 2/2 [==============================] - 3s 812ms/step - loss: 7.5012e-04 - custom_metric: -0.4517
# Epoch 372/2000
# 2/2 [==============================] - 3s 661ms/step - loss: 7.4589e-04 - custom_metric: -0.4432
# Epoch 373/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 8.1968e-04 - custom_metric: -1.1372
# Epoch 374/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 7.7701e-04 - custom_metric: -1.6517
# Epoch 375/2000
# 2/2 [==============================] - 3s 1s/step - loss: 7.5716e-04 - custom_metric: -0.4704
# Epoch 376/2000
# 2/2 [==============================] - 3s 707ms/step - loss: 7.6662e-04 - custom_metric: -0.4012
# Epoch 377/2000
# 2/2 [==============================] - 3s 698ms/step - loss: 7.9082e-04 - custom_metric: -0.0902
# Epoch 378/2000
# 2/2 [==============================] - 3s 660ms/step - loss: 8.2352e-04 - custom_metric: 0.0447
# Epoch 379/2000
# 2/2 [==============================] - 3s 840ms/step - loss: 7.9471e-04 - custom_metric: -0.0918
# Epoch 380/2000
# 2/2 [==============================] - 3s 722ms/step - loss: 7.9784e-04 - custom_metric: 0.0039
# Epoch 381/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 7.6495e-04 - custom_metric: -0.0783
# Epoch 382/2000
# 2/2 [==============================] - 2s 660ms/step - loss: 7.4713e-04 - custom_metric: -1.7947
# Epoch 383/2000
# 2/2 [==============================] - 3s 676ms/step - loss: 7.9412e-04 - custom_metric: -0.3763
# Epoch 384/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 7.5719e-04 - custom_metric: -0.4350
# Epoch 385/2000
# 2/2 [==============================] - 3s 668ms/step - loss: 7.5910e-04 - custom_metric: -0.2347
# Epoch 386/2000
# 2/2 [==============================] - 3s 697ms/step - loss: 7.3864e-04 - custom_metric: 0.3209
# Epoch 387/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 7.7880e-04 - custom_metric: -0.1115
# Epoch 388/2000
# 2/2 [==============================] - 3s 1s/step - loss: 7.8853e-04 - custom_metric: -0.0837
# Epoch 389/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 7.8331e-04 - custom_metric: -1.2783
# Epoch 390/2000
# 2/2 [==============================] - 3s 671ms/step - loss: 7.8362e-04 - custom_metric: 0.0051
# Epoch 391/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 7.4108e-04 - custom_metric: -0.2978
# Epoch 392/2000
# 2/2 [==============================] - 3s 847ms/step - loss: 7.5852e-04 - custom_metric: -0.0926
# Epoch 393/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 7.4451e-04 - custom_metric: -0.0200
# Epoch 394/2000
# 2/2 [==============================] - 3s 675ms/step - loss: 7.7690e-04 - custom_metric: 0.0054
# Epoch 395/2000
# 2/2 [==============================] - 3s 672ms/step - loss: 7.4073e-04 - custom_metric: -1.1241
# Epoch 396/2000
# 2/2 [==============================] - 3s 682ms/step - loss: 7.4117e-04 - custom_metric: -0.0628
# Epoch 397/2000
# 2/2 [==============================] - 3s 729ms/step - loss: 7.1619e-04 - custom_metric: 0.2611
# Epoch 398/2000
# 2/2 [==============================] - 3s 677ms/step - loss: 7.4446e-04 - custom_metric: -0.6632
# Epoch 399/2000
# 2/2 [==============================] - 3s 664ms/step - loss: 7.3686e-04 - custom_metric: -0.8932
# Epoch 400/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 7.9770e-04 - custom_metric: -0.1095
# Epoch 401/2000
# 2/2 [==============================] - 3s 1s/step - loss: 7.2827e-04 - custom_metric: 0.0681
# Epoch 402/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 7.2403e-04 - custom_metric: -0.1302
# Epoch 403/2000
# 2/2 [==============================] - 3s 686ms/step - loss: 7.2439e-04 - custom_metric: -0.0496
# Epoch 404/2000
# 2/2 [==============================] - 3s 727ms/step - loss: 8.2759e-04 - custom_metric: -2.0472
# Epoch 405/2000
# 2/2 [==============================] - 3s 867ms/step - loss: 7.4432e-04 - custom_metric: -0.0740
# Epoch 406/2000
# 2/2 [==============================] - 3s 683ms/step - loss: 9.3119e-04 - custom_metric: -0.7217
# Epoch 407/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 7.4603e-04 - custom_metric: -0.0765
# Epoch 408/2000
# 2/2 [==============================] - 3s 731ms/step - loss: 9.1366e-04 - custom_metric: -0.2076
# Epoch 409/2000
# 2/2 [==============================] - 3s 718ms/step - loss: 7.8281e-04 - custom_metric: -0.4311
# Epoch 410/2000
# 2/2 [==============================] - 3s 668ms/step - loss: 8.7754e-04 - custom_metric: -0.2475
# Epoch 411/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 9.1768e-04 - custom_metric: -0.4618
# Epoch 412/2000
# 2/2 [==============================] - 3s 670ms/step - loss: 8.5325e-04 - custom_metric: -0.1906
# Epoch 413/2000
# 2/2 [==============================] - 3s 720ms/step - loss: 7.6339e-04 - custom_metric: -0.0536
# Epoch 414/2000
# 2/2 [==============================] - 3s 1s/step - loss: 7.6714e-04 - custom_metric: -1.2697
# Epoch 415/2000
# 2/2 [==============================] - 3s 691ms/step - loss: 7.4854e-04 - custom_metric: -0.2257
# Epoch 416/2000
# 2/2 [==============================] - 3s 662ms/step - loss: 7.6585e-04 - custom_metric: -0.2304
# Epoch 417/2000
# 2/2 [==============================] - 3s 674ms/step - loss: 7.6158e-04 - custom_metric: -0.1112
# Epoch 418/2000
# 2/2 [==============================] - 3s 856ms/step - loss: 7.6164e-04 - custom_metric: -0.1790
# Epoch 419/2000
# 2/2 [==============================] - 3s 669ms/step - loss: 7.4481e-04 - custom_metric: -1.0979
# Epoch 420/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 7.3566e-04 - custom_metric: -0.0520
# Epoch 421/2000
# 2/2 [==============================] - 3s 713ms/step - loss: 7.3898e-04 - custom_metric: 0.3163
# Epoch 422/2000
# 2/2 [==============================] - 3s 725ms/step - loss: 7.5302e-04 - custom_metric: -0.7842
# Epoch 423/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 7.4249e-04 - custom_metric: -0.0296
# Epoch 424/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 7.1666e-04 - custom_metric: 0.0331
# Epoch 425/2000
# 2/2 [==============================] - 3s 678ms/step - loss: 8.3082e-04 - custom_metric: -1.1752
# Epoch 426/2000
# 2/2 [==============================] - 3s 668ms/step - loss: 6.8466e-04 - custom_metric: 0.0208
# Epoch 427/2000
# 2/2 [==============================] - 3s 1s/step - loss: 8.5536e-04 - custom_metric: -0.9448
# Epoch 428/2000
# 2/2 [==============================] - 3s 680ms/step - loss: 7.0380e-04 - custom_metric: -0.0366
# Epoch 429/2000
# 2/2 [==============================] - 3s 707ms/step - loss: 8.3614e-04 - custom_metric: -1.2650
# Epoch 430/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 7.3017e-04 - custom_metric: -0.0519
# Epoch 431/2000
# 2/2 [==============================] - 3s 986ms/step - loss: 8.9717e-04 - custom_metric: -0.2807
# Epoch 432/2000
# 2/2 [==============================] - 3s 686ms/step - loss: 7.6127e-04 - custom_metric: -0.9892
# Epoch 433/2000
# 2/2 [==============================] - 3s 686ms/step - loss: 8.8916e-04 - custom_metric: -0.8840
# Epoch 434/2000
# 2/2 [==============================] - 3s 716ms/step - loss: 7.1470e-04 - custom_metric: 0.0880
# Epoch 435/2000
# 2/2 [==============================] - 3s 720ms/step - loss: 8.8597e-04 - custom_metric: -0.2490
# Epoch 436/2000
# 2/2 [==============================] - 4s 719ms/step - loss: 8.2322e-04 - custom_metric: -0.2523
# Epoch 437/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 7.7896e-04 - custom_metric: -0.1679
# Epoch 438/2000
# 2/2 [==============================] - 3s 672ms/step - loss: 7.4936e-04 - custom_metric: -1.1320
# Epoch 439/2000
# 2/2 [==============================] - 3s 702ms/step - loss: 7.8361e-04 - custom_metric: -0.2491
# Epoch 440/2000
# ...
# Epoch 1857/2000
# 2/2 [==============================] - 3s 725ms/step - loss: 0.0089 - custom_metric: -11.5876
# Epoch 1858/2000
# 2/2 [==============================] - 3s 725ms/step - loss: 0.0447 - custom_metric: -70.3532
# Epoch 1859/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0654 - custom_metric: -209.4275
# Epoch 1860/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 0.0157 - custom_metric: -21.4455
# Epoch 1861/2000
# 2/2 [==============================] - 3s 730ms/step - loss: 0.0712 - custom_metric: -112.7636
# Epoch 1862/2000
# 2/2 [==============================] - 3s 693ms/step - loss: 0.1408 - custom_metric: -186.0583
# Epoch 1863/2000
# 2/2 [==============================] - 3s 733ms/step - loss: 0.1462 - custom_metric: -430.1911
# Epoch 1864/2000
# 2/2 [==============================] - 3s 691ms/step - loss: 0.2470 - custom_metric: -458.3987
# Epoch 1865/2000
# 2/2 [==============================] - 3s 716ms/step - loss: 0.1109 - custom_metric: -3069.2888
# Epoch 1866/2000
# 2/2 [==============================] - 3s 731ms/step - loss: 0.1179 - custom_metric: -1478.3308
# Epoch 1867/2000
# 2/2 [==============================] - 3s 710ms/step - loss: 0.2922 - custom_metric: -2212.3264
# Epoch 1868/2000
# 2/2 [==============================] - 3s 679ms/step - loss: 0.4623 - custom_metric: -578.5425
# Epoch 1869/2000
# 2/2 [==============================] - 3s 712ms/step - loss: 0.4325 - custom_metric: -1109.9133
# Epoch 1870/2000
# 2/2 [==============================] - 3s 729ms/step - loss: 0.6459 - custom_metric: -605.3840
# Epoch 1871/2000
# 2/2 [==============================] - 3s 719ms/step - loss: 0.8064 - custom_metric: -718.3243
# Epoch 1872/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.5171 - custom_metric: -2856.4539
# Epoch 1873/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 0.4851 - custom_metric: -644.8488
# Epoch 1874/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 0.2228 - custom_metric: -2624.2209
# Epoch 1875/2000
# 2/2 [==============================] - 3s 711ms/step - loss: 0.5069 - custom_metric: -2876.3745
# Epoch 1876/2000
# 2/2 [==============================] - 3s 976ms/step - loss: 1.0969 - custom_metric: -939.2196
# Epoch 1877/2000
# 2/2 [==============================] - 3s 720ms/step - loss: 0.9720 - custom_metric: -4234.9775
# Epoch 1878/2000
# 2/2 [==============================] - 3s 696ms/step - loss: 0.6533 - custom_metric: -1704.1896
# Epoch 1879/2000
# 2/2 [==============================] - 3s 712ms/step - loss: 0.5196 - custom_metric: -689.7500
# Epoch 1880/2000
# 2/2 [==============================] - 3s 703ms/step - loss: 0.8502 - custom_metric: -769.3455
# Epoch 1881/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 0.5114 - custom_metric: -951.0151
# Epoch 1882/2000
# 2/2 [==============================] - 3s 711ms/step - loss: 0.2330 - custom_metric: -326.1778
# Epoch 1883/2000
# 2/2 [==============================] - 3s 706ms/step - loss: 0.3581 - custom_metric: -5882.9414
# Epoch 1884/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.3515 - custom_metric: -4893.2319
# Epoch 1885/2000
# 2/2 [==============================] - 3s 874ms/step - loss: 0.2946 - custom_metric: -612.9194
# Epoch 1886/2000
# 2/2 [==============================] - 3s 717ms/step - loss: 0.5703 - custom_metric: -988.3163
# Epoch 1887/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 0.1502 - custom_metric: -673.8577
# Epoch 1888/2000
# 2/2 [==============================] - 3s 693ms/step - loss: 0.3692 - custom_metric: -1037.8552
# Epoch 1889/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.1235 - custom_metric: -274.7246
# Epoch 1890/2000
# 2/2 [==============================] - 3s 707ms/step - loss: 0.1412 - custom_metric: -644.5413
# Epoch 1891/2000
# 2/2 [==============================] - 3s 702ms/step - loss: 0.0561 - custom_metric: -306.5955
# Epoch 1892/2000
# 2/2 [==============================] - 3s 707ms/step - loss: 0.1544 - custom_metric: -548.5978
# Epoch 1893/2000
# 2/2 [==============================] - 3s 838ms/step - loss: 0.0930 - custom_metric: -178.3893
# Epoch 1894/2000
# 2/2 [==============================] - 3s 724ms/step - loss: 0.0360 - custom_metric: -55.5797
# Epoch 1895/2000
# 2/2 [==============================] - 3s 717ms/step - loss: 0.0686 - custom_metric: -87.7710
# Epoch 1896/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 0.0493 - custom_metric: -141.7597
# Epoch 1897/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 0.0233 - custom_metric: -87.5315
# Epoch 1898/2000
# 2/2 [==============================] - 3s 751ms/step - loss: 0.0367 - custom_metric: -90.1529
# Epoch 1899/2000
# 2/2 [==============================] - 3s 717ms/step - loss: 0.0229 - custom_metric: -29.5802
# Epoch 1900/2000
# 2/2 [==============================] - 3s 714ms/step - loss: 0.0314 - custom_metric: -127.2740
# Epoch 1901/2000
# 2/2 [==============================] - 3s 707ms/step - loss: 0.0217 - custom_metric: -70.4719
# Epoch 1902/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0290 - custom_metric: -76.6284
# Epoch 1903/2000
# 2/2 [==============================] - 3s 747ms/step - loss: 0.0166 - custom_metric: -47.4506
# Epoch 1904/2000
# 2/2 [==============================] - 3s 693ms/step - loss: 0.0130 - custom_metric: -25.9003
# Epoch 1905/2000
# 2/2 [==============================] - 3s 717ms/step - loss: 0.0231 - custom_metric: -61.1872
# Epoch 1906/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0098 - custom_metric: -23.0071
# Epoch 1907/2000
# 2/2 [==============================] - 3s 716ms/step - loss: 0.0173 - custom_metric: -93.4211
# Epoch 1908/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.0076 - custom_metric: -44.4050
# Epoch 1909/2000
# 2/2 [==============================] - 3s 742ms/step - loss: 0.0154 - custom_metric: -32.6556
# Epoch 1910/2000
# 2/2 [==============================] - 3s 752ms/step - loss: 0.0081 - custom_metric: -41.0187
# Epoch 1911/2000
# 2/2 [==============================] - 3s 728ms/step - loss: 0.0130 - custom_metric: -16.8241
# Epoch 1912/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 0.0065 - custom_metric: -27.3216
# Epoch 1913/2000
# 2/2 [==============================] - 3s 712ms/step - loss: 0.0048 - custom_metric: -26.9340
# Epoch 1914/2000
# 2/2 [==============================] - 3s 680ms/step - loss: 0.0066 - custom_metric: -6.2726
# Epoch 1915/2000
# 2/2 [==============================] - 3s 688ms/step - loss: 0.0030 - custom_metric: -3.2014
# Epoch 1916/2000
# 2/2 [==============================] - 3s 702ms/step - loss: 0.0060 - custom_metric: -32.1093
# Epoch 1917/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 0.0028 - custom_metric: -9.5478
# Epoch 1918/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 0.0062 - custom_metric: -7.7322
# Epoch 1919/2000
# 2/2 [==============================] - 3s 1s/step - loss: 0.0032 - custom_metric: -23.2507
# Epoch 1920/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 0.0070 - custom_metric: -8.8336
# Epoch 1921/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 0.0040 - custom_metric: -14.3802
# Epoch 1922/2000
# 2/2 [==============================] - 3s 705ms/step - loss: 0.0052 - custom_metric: -28.9772
# Epoch 1923/2000
# 2/2 [==============================] - 3s 816ms/step - loss: 0.0060 - custom_metric: -5.9900
# Epoch 1924/2000
# 2/2 [==============================] - 3s 734ms/step - loss: 0.0027 - custom_metric: -21.3943
# Epoch 1925/2000
# 2/2 [==============================] - 3s 695ms/step - loss: 0.0048 - custom_metric: -4.9025
# Epoch 1926/2000
# 2/2 [==============================] - 3s 758ms/step - loss: 0.0020 - custom_metric: -38.6730
# Epoch 1927/2000
# 2/2 [==============================] - 3s 698ms/step - loss: 0.0035 - custom_metric: -4.0406
# Epoch 1928/2000
# 2/2 [==============================] - 3s 700ms/step - loss: 0.0027 - custom_metric: -2.8763
# Epoch 1929/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 0.0018 - custom_metric: -6.0353
# Epoch 1930/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 0.0044 - custom_metric: -7.0430
# Epoch 1931/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 0.0013 - custom_metric: -6.7409
# Epoch 1932/2000
# 2/2 [==============================] - 3s 904ms/step - loss: 0.0032 - custom_metric: -5.8287
# Epoch 1933/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 0.0018 - custom_metric: -1.5147
# Epoch 1934/2000
# 2/2 [==============================] - 3s 705ms/step - loss: 0.0014 - custom_metric: -0.8470
# Epoch 1935/2000
# 2/2 [==============================] - 3s 739ms/step - loss: 0.0016 - custom_metric: -1.0148
# Epoch 1936/2000
# 2/2 [==============================] - 3s 1s/step - loss: 9.0632e-04 - custom_metric: -1.0163
# Epoch 1937/2000
# 2/2 [==============================] - 3s 709ms/step - loss: 0.0011 - custom_metric: -1.5903
# Epoch 1938/2000
# 2/2 [==============================] - 3s 725ms/step - loss: 0.0011 - custom_metric: -0.9421
# Epoch 1939/2000
# 2/2 [==============================] - 3s 723ms/step - loss: 9.0191e-04 - custom_metric: -0.2795
# Epoch 1940/2000
# 2/2 [==============================] - 3s 1s/step - loss: 9.6361e-04 - custom_metric: -1.7116
# Epoch 1941/2000
# 2/2 [==============================] - 3s 708ms/step - loss: 7.7255e-04 - custom_metric: -0.0709
# Epoch 1942/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 8.1792e-04 - custom_metric: -0.9443
# Epoch 1943/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 6.9703e-04 - custom_metric: 0.4213
# Epoch 1944/2000
# 2/2 [==============================] - 3s 712ms/step - loss: 6.9714e-04 - custom_metric: -0.0277
# Epoch 1945/2000
# 2/2 [==============================] - 8s 2s/step - loss: 6.8465e-04 - custom_metric: 0.0087
# Epoch 1946/2000
# 2/2 [==============================] - 6s 2s/step - loss: 6.9069e-04 - custom_metric: -0.0723
# Epoch 1947/2000
# 2/2 [==============================] - 3s 697ms/step - loss: 6.4317e-04 - custom_metric: 0.0715
# Epoch 1948/2000
# 2/2 [==============================] - 3s 713ms/step - loss: 6.6513e-04 - custom_metric: 0.0478
# Epoch 1949/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 6.5314e-04 - custom_metric: 0.0106
# Epoch 1950/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 5.9808e-04 - custom_metric: 0.3834
# Epoch 1951/2000
# 2/2 [==============================] - 3s 726ms/step - loss: 6.2964e-04 - custom_metric: 0.0777
# Epoch 1952/2000
# 2/2 [==============================] - 3s 692ms/step - loss: 5.9171e-04 - custom_metric: 0.4107
# Epoch 1953/2000
# 2/2 [==============================] - 3s 702ms/step - loss: 6.0794e-04 - custom_metric: 0.4232
# Epoch 1954/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 6.0955e-04 - custom_metric: 0.1208
# Epoch 1955/2000
# 2/2 [==============================] - 3s 1s/step - loss: 5.8365e-04 - custom_metric: 0.2676
# Epoch 1956/2000
# 2/2 [==============================] - 3s 704ms/step - loss: 5.8762e-04 - custom_metric: 0.1056
# Epoch 1957/2000
# 2/2 [==============================] - 3s 694ms/step - loss: 5.7776e-04 - custom_metric: 0.4057
# Epoch 1958/2000
# 2/2 [==============================] - 3s 723ms/step - loss: 5.8465e-04 - custom_metric: 0.5110
# Epoch 1959/2000
# 2/2 [==============================] - 3s 996ms/step - loss: 5.7378e-04 - custom_metric: 0.1234
# Epoch 1960/2000
# 2/2 [==============================] - 3s 690ms/step - loss: 5.8191e-04 - custom_metric: 0.3941
# Epoch 1961/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 5.7804e-04 - custom_metric: 0.4686
# Epoch 1962/2000
# 2/2 [==============================] - 3s 720ms/step - loss: 5.8510e-04 - custom_metric: 0.4300
# Epoch 1963/2000
# 2/2 [==============================] - 3s 681ms/step - loss: 5.7385e-04 - custom_metric: 0.4694
# Epoch 1964/2000
# 2/2 [==============================] - 3s 711ms/step - loss: 5.7125e-04 - custom_metric: 0.1521
# Epoch 1965/2000
# 2/2 [==============================] - 3s 699ms/step - loss: 5.7099e-04 - custom_metric: 0.4787
# Epoch 1966/2000
# 2/2 [==============================] - 3s 710ms/step - loss: 5.6762e-04 - custom_metric: 0.3655
# Epoch 1967/2000
# 2/2 [==============================] - 3s 689ms/step - loss: 5.6703e-04 - custom_metric: 0.1685
# Epoch 1968/2000
# 2/2 [==============================] - 3s 731ms/step - loss: 5.6669e-04 - custom_metric: 0.4761
# Epoch 1969/2000
# 2/2 [==============================] - 3s 691ms/step - loss: 5.6279e-04 - custom_metric: 0.5206
# Epoch 1970/2000
# 2/2 [==============================] - 3s 724ms/step - loss: 5.6472e-04 - custom_metric: 0.5487
# Epoch 1971/2000
# 2/2 [==============================] - 3s 725ms/step - loss: 5.6450e-04 - custom_metric: 0.1500
# Epoch 1972/2000
# 2/2 [==============================] - 3s 1s/step - loss: 5.6492e-04 - custom_metric: 0.5375
# Epoch 1973/2000
# 2/2 [==============================] - 3s 717ms/step - loss: 5.6386e-04 - custom_metric: 0.5101
# Epoch 1974/2000
# 2/2 [==============================] - 3s 708ms/step - loss: 5.6200e-04 - custom_metric: 0.5147
# Epoch 1975/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 5.6194e-04 - custom_metric: 0.1344
# Epoch 1976/2000
# 2/2 [==============================] - 3s 790ms/step - loss: 5.6021e-04 - custom_metric: 0.1438
# Epoch 1977/2000
# 2/2 [==============================] - 3s 708ms/step - loss: 5.6142e-04 - custom_metric: 0.5056
# Epoch 1978/2000
# 2/2 [==============================] - 3s 713ms/step - loss: 5.6073e-04 - custom_metric: 0.1653
# Epoch 1979/2000
# 2/2 [==============================] - 3s 730ms/step - loss: 5.6005e-04 - custom_metric: 0.5229
# Epoch 1980/2000
# 2/2 [==============================] - 3s 736ms/step - loss: 5.6565e-04 - custom_metric: 0.5071
# Epoch 1981/2000
# 2/2 [==============================] - 3s 696ms/step - loss: 5.6172e-04 - custom_metric: 0.1855
# Epoch 1982/2000
# 2/2 [==============================] - 3s 698ms/step - loss: 5.6767e-04 - custom_metric: 0.1182
# Epoch 1983/2000
# 2/2 [==============================] - 3s 740ms/step - loss: 5.6406e-04 - custom_metric: 0.5430
# Epoch 1984/2000
# 2/2 [==============================] - 3s 733ms/step - loss: 5.6548e-04 - custom_metric: 0.5096
# Epoch 1985/2000
# 2/2 [==============================] - 3s 1s/step - loss: 5.6277e-04 - custom_metric: 0.4937
# Epoch 1986/2000
# 2/2 [==============================] - 3s 698ms/step - loss: 5.5933e-04 - custom_metric: 0.2398
# Epoch 1987/2000
# 2/2 [==============================] - 3s 745ms/step - loss: 5.6684e-04 - custom_metric: 0.5652
# Epoch 1988/2000
# 2/2 [==============================] - 3s 696ms/step - loss: 5.5765e-04 - custom_metric: 0.5642
# Epoch 1989/2000
# 2/2 [==============================] - 3s 1s/step - loss: 5.6474e-04 - custom_metric: 0.5305
# Epoch 1990/2000
# 2/2 [==============================] - 3s 716ms/step - loss: 5.5956e-04 - custom_metric: 0.2936
# Epoch 1991/2000
# 2/2 [==============================] - 3s 732ms/step - loss: 5.6059e-04 - custom_metric: 0.5593
# Epoch 1992/2000
# 2/2 [==============================] - 3s 696ms/step - loss: 5.5805e-04 - custom_metric: 0.5535
# Epoch 1993/2000
# 2/2 [==============================] - 3s 905ms/step - loss: 5.5843e-04 - custom_metric: 0.1377
# Epoch 1994/2000
# 2/2 [==============================] - 3s 710ms/step - loss: 5.6068e-04 - custom_metric: 0.2785
# Epoch 1995/2000
# 2/2 [==============================] - 3s 713ms/step - loss: 5.6117e-04 - custom_metric: 0.3208
# Epoch 1996/2000
# 2/2 [==============================] - 3s 701ms/step - loss: 5.5882e-04 - custom_metric: 0.1732
# Epoch 1997/2000
# 2/2 [==============================] - 3s 732ms/step - loss: 5.6210e-04 - custom_metric: 0.5343
# Epoch 1998/2000
# 2/2 [==============================] - 3s 751ms/step - loss: 5.6560e-04 - custom_metric: 0.1722
# Epoch 1999/2000
# 2/2 [==============================] - 3s 757ms/step - loss: 5.6237e-04 - custom_metric: 0.3674
# Epoch 2000/2000
# 2/2 [==============================] - 3s 711ms/step - loss: 5.6459e-04 - custom_metric: 0.4790

# %% [markdown]
# Not too bad of an R2, not the best, but not bad

# %%
test_out = neur.predict(x_finaleval)
output = finaleval[['Diff']]
output['predicted'] = test_out
output['actual'] = y_finaleval
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print("R2: ", r2_score(output['actual'], output['predicted']))
print("MeanSqError: ",np.sqrt(mean_squared_error(output['actual'], output['predicted'])))
print("MeanAbsError: ", mean_absolute_error(output['actual'],output['predicted']))
output = output[['predicted','actual']]
output
# Out:
# 1/1 [==============================] - 0s 139ms/step
# R2:  0.5636558681556474
# MeanSqError:  0.0038486911072155108
# MeanAbsError:  0.0030806344814022658
# <ipython-input-42-14c14dcd54e4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['predicted'] = test_out
# <ipython-input-42-14c14dcd54e4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['actual'] = y_finaleval
#             predicted    actual
# Timestamp
# 2023-07-23  -0.004525 -0.001893
# 2023-07-30   0.014654  0.013668
# 2023-08-06   0.003119  0.006580
# 2023-08-13   0.002854  0.006927
# 2023-08-20   0.002569  0.005228
# 2023-08-27   0.008864  0.010212
# 2023-09-03   0.002596  0.002310
# 2023-09-10  -0.008040 -0.001680
# 2023-09-17  -0.000203 -0.002312
# 2023-09-24  -0.003507 -0.002727
# 2023-10-01   0.018677  0.010144
# 2023-10-08   0.016476  0.012737

# %% [markdown]
# The result shown here is the difference with respect to the next week, so I need to start with the value and difference from the week of July 16, after reversing to a arc tanh

# %%
output = output[['predicted']]
output['predictedArcTanh'] = output['predicted'].apply(lambda x: math.atanh(x))
output
# Out:
#             predicted  predictedArcTanh
# Timestamp
# 2023-07-23  -0.004525         -0.004525
# 2023-07-30   0.014654          0.014655
# 2023-08-06   0.003119          0.003119
# 2023-08-13   0.002854          0.002854
# 2023-08-20   0.002569          0.002569
# 2023-08-27   0.008864          0.008864
# 2023-09-03   0.002596          0.002596
# 2023-09-10  -0.008040         -0.008040
# 2023-09-17  -0.000203         -0.000203
# 2023-09-24  -0.003507         -0.003507
# 2023-10-01   0.018677          0.018680
# 2023-10-08   0.016476          0.016478

# %%
ydf[(ydf.index=='2023-07-16') | (ydf.index=='2023-07-23')]
# Out:
#             GASREGW  seasonal_32  seasonal_37  seasonal_52  seasonal_65  \
# DATE
# 2023-07-16    3.559    -0.131384    -0.026409     0.341058    -0.141251
# 2023-07-23    3.596    -0.135410     0.032115     0.279535    -0.089731
#
#             seasonal_104     Trend     Resid      Diff
# DATE
# 2023-07-16     -0.819315  4.373422 -0.037122 -0.001443
# 2023-07-23     -0.840544  4.385714 -0.035678 -0.001893

# %% [markdown]
# Now, these are predicted values of the residuals.

# %%
output['PredResid'] = np.nan

start = 0
prevval = 0
for index, row in output.iterrows():
 if start == 0:
  prevval = -0.037122 - row['predictedArcTanh']
 else:
  prevval = prevval - row['predictedArcTanh']
 output.at[index, 'PredResid'] = prevval

output = output[['PredResid']]
output
# Out:
#             PredResid
# Timestamp
# 2023-07-23  -0.032597
# 2023-07-30  -0.051777
# 2023-08-06  -0.040241
# 2023-08-13  -0.039976
# 2023-08-20  -0.039691
# 2023-08-27  -0.045986
# 2023-09-03  -0.039718
# 2023-09-10  -0.029082
# 2023-09-17  -0.036919
# 2023-09-24  -0.033615
# 2023-10-01  -0.055802
# 2023-10-08  -0.053600

# %% [markdown]
# Now I estimate the trend with a simple linear regression.

# %%
ydf['rown'] = range(len(ydf))
setreg = ydf[ydf.index <'2023-07-23']
setreg = setreg[['Trend','rown']]
mod = LinearRegression().fit(setreg[['rown']], setreg['Trend'])
setreg['PredTrend'] = mod.predict(setreg[['rown']])
plt.scatter(setreg['rown'], setreg['Trend'], color="black")
plt.plot(setreg['rown'], setreg['PredTrend'], color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
outcome = ydf[ydf.index >='2023-07-23']
outcome = outcome[['GASREGW','rown']]
outcome['PredTrend'] = mod.predict(outcome[['rown']])
outcome
# Out:
#             GASREGW  rown  PredTrend
# DATE
# 2023-07-23    3.596   249   4.187386
# 2023-07-30    3.757   250   4.197076
# 2023-08-06    3.828   251   4.206766
# 2023-08-13    3.850   252   4.216456
# 2023-08-20    3.868   253   4.226146
# 2023-08-27    3.813   254   4.235836
# 2023-09-03    3.807   255   4.245526
# 2023-09-10    3.822   256   4.255217
# 2023-09-17    3.878   257   4.264907
# 2023-09-24    3.837   258   4.274597
# 2023-10-01    3.798   259   4.284287
# 2023-10-08    3.684   260   4.293977
# 2023-10-15    3.576   261   4.303667

# %% [markdown]
# For the seasonal values, I fit them to a cosine function by creating a custom numpy function with the model I want to fit and giving it "good" seeds for the parameters (amplitude, frequency, fase angle, and offset). I had to run it several times since the results were very sensible for the seeds. This is predicting seasonal_32.

# %%
from scipy import optimize
from sklearn.preprocessing import MinMaxScaler
setreg = ydf[ydf.index <'2023-07-23']
setreg = setreg[['seasonal_32','rown']]
def fit_func(x, a, b, c, d):
    return a*np.cos(b*x+c) + d
params, params_covariance = optimize.curve_fit(fit_func, setreg['rown'], setreg['seasonal_32'], p0=(10,.19,0,0))

setreg['Predseasonal_32'] = setreg['rown'].apply(lambda x: fit_func(x, *params))
plt.scatter(setreg['rown'], setreg['seasonal_32'], color="black")
plt.plot(setreg['rown'], setreg['Predseasonal_32'], color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#assign to outcome
outcome['Predseasonal_32'] = outcome['rown'].apply(lambda x: fit_func(x, *params))
outcome
# Out:
#             GASREGW  rown  PredTrend  Predseasonal_32
# DATE
# 2023-07-23    3.596   249   4.187386         0.131542
# 2023-07-30    3.757   250   4.197076         0.145835
# 2023-08-06    3.828   251   4.206766         0.154386
# 2023-08-13    3.850   252   4.216456         0.156857
# 2023-08-20    3.868   253   4.226146         0.153150
# 2023-08-27    3.813   254   4.235836         0.143411
# 2023-09-03    3.807   255   4.245526         0.128027
# 2023-09-10    3.822   256   4.255217         0.107607
# 2023-09-17    3.878   257   4.264907         0.082960
# 2023-09-24    3.837   258   4.274597         0.055063
# 2023-10-01    3.798   259   4.284287         0.025023
# 2023-10-08    3.684   260   4.293977        -0.005972
# 2023-10-15    3.576   261   4.303667        -0.036693

# %% [markdown]
# Predict seasonal_37

# %%
from scipy import optimize
from sklearn.preprocessing import MinMaxScaler
setreg = ydf[ydf.index <'2023-07-23']
setreg = setreg[['seasonal_37','rown']]
def fit_func(x, a, b, c, d):
    return a*np.cos(b*x+c) + d
params, params_covariance = optimize.curve_fit(fit_func, setreg['rown'], setreg['seasonal_37'], p0=(10,.17,0,0))

setreg['Predseasonal_37'] = setreg['rown'].apply(lambda x: fit_func(x, *params))
plt.scatter(setreg['rown'], setreg['seasonal_37'], color="black")
plt.plot(setreg['rown'], setreg['Predseasonal_37'], color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#assign to outcome
outcome['Predseasonal_37'] = outcome['rown'].apply(lambda x: fit_func(x, *params))
outcome
# Out:
#             GASREGW  rown  PredTrend  Predseasonal_32  Predseasonal_37
# DATE
# 2023-07-23    3.596   249   4.187386         0.131542        -0.062990
# 2023-07-30    3.757   250   4.197076         0.145835        -0.057636
# 2023-08-06    3.828   251   4.206766         0.154386        -0.050904
# 2023-08-13    3.850   252   4.216456         0.156857        -0.042962
# 2023-08-20    3.868   253   4.226146         0.153150        -0.034008
# 2023-08-27    3.813   254   4.235836         0.143411        -0.024264
# 2023-09-03    3.807   255   4.245526         0.128027        -0.013973
# 2023-09-10    3.822   256   4.255217         0.107607        -0.003392
# 2023-09-17    3.878   257   4.264907         0.082960         0.007216
# 2023-09-24    3.837   258   4.274597         0.055063         0.017587
# 2023-10-01    3.798   259   4.284287         0.025023         0.027461
# 2023-10-08    3.684   260   4.293977        -0.005972         0.036594
# 2023-10-15    3.576   261   4.303667        -0.036693         0.044757

# %% [markdown]
# Predict seasonal 52

# %%
from scipy import optimize
from sklearn.preprocessing import MinMaxScaler
setreg = ydf[ydf.index <'2023-07-23']
setreg = setreg[['seasonal_52','rown']]
def fit_func(x, a, b, c, d):
    return a*np.cos(b*x+c) + d
params, params_covariance = optimize.curve_fit(fit_func, setreg['rown'], setreg['seasonal_52'], p0=(10,.13,0,0))

setreg['Predseasonal_52'] = setreg['rown'].apply(lambda x: fit_func(x, *params))
plt.scatter(setreg['rown'], setreg['seasonal_52'], color="black")
plt.plot(setreg['rown'], setreg['Predseasonal_52'], color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#assign to outcome
outcome['Predseasonal_52'] = outcome['rown'].apply(lambda x: fit_func(x, *params))
outcome
# Out:
#             GASREGW  rown  PredTrend  Predseasonal_32  Predseasonal_37  \
# DATE
# 2023-07-23    3.596   249   4.187386         0.131542        -0.062990
# 2023-07-30    3.757   250   4.197076         0.145835        -0.057636
# 2023-08-06    3.828   251   4.206766         0.154386        -0.050904
# 2023-08-13    3.850   252   4.216456         0.156857        -0.042962
# 2023-08-20    3.868   253   4.226146         0.153150        -0.034008
# 2023-08-27    3.813   254   4.235836         0.143411        -0.024264
# 2023-09-03    3.807   255   4.245526         0.128027        -0.013973
# 2023-09-10    3.822   256   4.255217         0.107607        -0.003392
# 2023-09-17    3.878   257   4.264907         0.082960         0.007216
# 2023-09-24    3.837   258   4.274597         0.055063         0.017587
# 2023-10-01    3.798   259   4.284287         0.025023         0.027461
# 2023-10-08    3.684   260   4.293977        -0.005972         0.036594
# 2023-10-15    3.576   261   4.303667        -0.036693         0.044757
#
#             Predseasonal_52
# DATE
# 2023-07-23         0.167339
# 2023-07-30         0.151655
# 2023-08-06         0.133757
# 2023-08-13         0.113924
# 2023-08-20         0.092462
# 2023-08-27         0.069703
# 2023-09-03         0.046000
# 2023-09-10         0.021720
# 2023-09-17        -0.002762
# 2023-09-24        -0.027065
# 2023-10-01        -0.050815
# 2023-10-08        -0.073643
# 2023-10-15        -0.095195

# %% [markdown]
# Predict seasonal 65

# %%
from scipy import optimize
from sklearn.preprocessing import MinMaxScaler
setreg = ydf[ydf.index <'2023-07-23']
setreg = setreg[['seasonal_65','rown']]
def fit_func(x, a, b, c, d):
    return a*np.cos(b*x+c) + d
params, params_covariance = optimize.curve_fit(fit_func, setreg['rown'], setreg['seasonal_65'], p0=(10,.1,0,0))

setreg['Predseasonal_65'] = setreg['rown'].apply(lambda x: fit_func(x, *params))
plt.scatter(setreg['rown'], setreg['seasonal_65'], color="black")
plt.plot(setreg['rown'], setreg['Predseasonal_65'], color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#assign to outcome
outcome['Predseasonal_65'] = outcome['rown'].apply(lambda x: fit_func(x, *params))
outcome
# Out:
#             GASREGW  rown  PredTrend  Predseasonal_32  Predseasonal_37  \
# DATE
# 2023-07-23    3.596   249   4.187386         0.131542        -0.062990
# 2023-07-30    3.757   250   4.197076         0.145835        -0.057636
# 2023-08-06    3.828   251   4.206766         0.154386        -0.050904
# 2023-08-13    3.850   252   4.216456         0.156857        -0.042962
# 2023-08-20    3.868   253   4.226146         0.153150        -0.034008
# 2023-08-27    3.813   254   4.235836         0.143411        -0.024264
# 2023-09-03    3.807   255   4.245526         0.128027        -0.013973
# 2023-09-10    3.822   256   4.255217         0.107607        -0.003392
# 2023-09-17    3.878   257   4.264907         0.082960         0.007216
# 2023-09-24    3.837   258   4.274597         0.055063         0.017587
# 2023-10-01    3.798   259   4.284287         0.025023         0.027461
# 2023-10-08    3.684   260   4.293977        -0.005972         0.036594
# 2023-10-15    3.576   261   4.303667        -0.036693         0.044757
#
#             Predseasonal_52  Predseasonal_65
# DATE
# 2023-07-23         0.167339        -0.068807
# 2023-07-30         0.151655        -0.060588
# 2023-08-06         0.133757        -0.051916
# 2023-08-13         0.113924        -0.042858
# 2023-08-20         0.092462        -0.033486
# 2023-08-27         0.069703        -0.023874
# 2023-09-03         0.046000        -0.014096
# 2023-09-10         0.021720        -0.004231
# 2023-09-17        -0.002762         0.005644
# 2023-09-24        -0.027065         0.015453
# 2023-10-01        -0.050815         0.025117
# 2023-10-08        -0.073643         0.034561
# 2023-10-15        -0.095195         0.043711

# %% [markdown]
# Predict seasonal 104

# %%
from scipy import optimize
from sklearn.preprocessing import MinMaxScaler
setreg = ydf[ydf.index <'2023-07-23']
setreg = setreg[['seasonal_104','rown']]
def fit_func(x, a, b, c, d):
    return a*np.cos(b*x+c) + d
params, params_covariance = optimize.curve_fit(fit_func, setreg['rown'], setreg['seasonal_104'], p0=(10,.05,0,0))

setreg['Predseasonal_104'] = setreg['rown'].apply(lambda x: fit_func(x, *params))
plt.scatter(setreg['rown'], setreg['seasonal_104'], color="black")
plt.plot(setreg['rown'], setreg['Predseasonal_104'], color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#assign to outcome
outcome['Predseasonal_104'] = outcome['rown'].apply(lambda x: fit_func(x, *params))
outcome
# Out:
#             GASREGW  rown  PredTrend  Predseasonal_32  Predseasonal_37  \
# DATE
# 2023-07-23    3.596   249   4.187386         0.131542        -0.062990
# 2023-07-30    3.757   250   4.197076         0.145835        -0.057636
# 2023-08-06    3.828   251   4.206766         0.154386        -0.050904
# 2023-08-13    3.850   252   4.216456         0.156857        -0.042962
# 2023-08-20    3.868   253   4.226146         0.153150        -0.034008
# 2023-08-27    3.813   254   4.235836         0.143411        -0.024264
# 2023-09-03    3.807   255   4.245526         0.128027        -0.013973
# 2023-09-10    3.822   256   4.255217         0.107607        -0.003392
# 2023-09-17    3.878   257   4.264907         0.082960         0.007216
# 2023-09-24    3.837   258   4.274597         0.055063         0.017587
# 2023-10-01    3.798   259   4.284287         0.025023         0.027461
# 2023-10-08    3.684   260   4.293977        -0.005972         0.036594
# 2023-10-15    3.576   261   4.303667        -0.036693         0.044757
#
#             Predseasonal_52  Predseasonal_65  Predseasonal_104
# DATE
# 2023-07-23         0.167339        -0.068807         -0.485424
# 2023-07-30         0.151655        -0.060588         -0.478575
# 2023-08-06         0.133757        -0.051916         -0.470784
# 2023-08-13         0.113924        -0.042858         -0.462066
# 2023-08-20         0.092462        -0.033486         -0.452439
# 2023-08-27         0.069703        -0.023874         -0.441921
# 2023-09-03         0.046000        -0.014096         -0.430534
# 2023-09-10         0.021720        -0.004231         -0.418301
# 2023-09-17        -0.002762         0.005644         -0.405246
# 2023-09-24        -0.027065         0.015453         -0.391395
# 2023-10-01        -0.050815         0.025117         -0.376776
# 2023-10-08        -0.073643         0.034561         -0.361417
# 2023-10-15        -0.095195         0.043711         -0.345350

# %% [markdown]
# Now, I aggregate all the components of the prediction and product a predicted price

# %%
final = pd.merge(outcome,output,left_index=True,right_index=True)
final['GASREGW_prep'] = final['PredTrend'] + final['Predseasonal_32'] + final['Predseasonal_37'] + final['Predseasonal_52'] + final['Predseasonal_65'] + final['Predseasonal_104'] + final['PredResid']
final
# Out:
#             GASREGW  rown  PredTrend  Predseasonal_32  Predseasonal_37  \
# 2023-07-23    3.596   249   4.187386         0.131542        -0.062990
# 2023-07-30    3.757   250   4.197076         0.145835        -0.057636
# 2023-08-06    3.828   251   4.206766         0.154386        -0.050904
# 2023-08-13    3.850   252   4.216456         0.156857        -0.042962
# 2023-08-20    3.868   253   4.226146         0.153150        -0.034008
# 2023-08-27    3.813   254   4.235836         0.143411        -0.024264
# 2023-09-03    3.807   255   4.245526         0.128027        -0.013973
# 2023-09-10    3.822   256   4.255217         0.107607        -0.003392
# 2023-09-17    3.878   257   4.264907         0.082960         0.007216
# 2023-09-24    3.837   258   4.274597         0.055063         0.017587
# 2023-10-01    3.798   259   4.284287         0.025023         0.027461
# 2023-10-08    3.684   260   4.293977        -0.005972         0.036594
#
#             Predseasonal_52  Predseasonal_65  Predseasonal_104  PredResid  \
# 2023-07-23         0.167339        -0.068807         -0.485424  -0.032597
# 2023-07-30         0.151655        -0.060588         -0.478575  -0.051777
# 2023-08-06         0.133757        -0.051916         -0.470784  -0.040241
# 2023-08-13         0.113924        -0.042858         -0.462066  -0.039976
# 2023-08-20         0.092462        -0.033486         -0.452439  -0.039691
# 2023-08-27         0.069703        -0.023874         -0.441921  -0.045986
# 2023-09-03         0.046000        -0.014096         -0.430534  -0.039718
# 2023-09-10         0.021720        -0.004231         -0.418301  -0.029082
# 2023-09-17        -0.002762         0.005644         -0.405246  -0.036919
# 2023-09-24        -0.027065         0.015453         -0.391395  -0.033615
# 2023-10-01        -0.050815         0.025117         -0.376776  -0.055802
# 2023-10-08        -0.073643         0.034561         -0.361417  -0.053600
#
#             GASREGW_prep
# 2023-07-23      3.836449
# 2023-07-30      3.845989
# 2023-08-06      3.881064
# 2023-08-13      3.899375
# 2023-08-20      3.912135
# 2023-08-27      3.912906
# 2023-09-03      3.921231
# 2023-09-10      3.929537
# 2023-09-17      3.915800
# 2023-09-24      3.910624
# 2023-10-01      3.878496
# 2023-10-08      3.870500

# %% [markdown]
# Plot of the predicted and the real prices

# %%
sns.lineplot(x='index', y='value', hue='variable', data=pd.melt(final[['GASREGW','GASREGW_prep']].reset_index(drop=False), ['index']))
plt.ylim(3,4.5)
# Out:
# (3.0, 4.5)

# %% [markdown]
# Which is very conservative in the price variation, but it is a general trend.
